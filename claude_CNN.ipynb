# %%
# %%
# ============================================================
# CELL 1: Imports and Configuration
# ============================================================
import os, warnings, numpy as np, pandas as pd
import torch, torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from torchvision import models
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import sys
import time

print("Torch:", torch.__version__, " | Numpy:", np.__version__, " | Python:", sys.version)

warnings.filterwarnings("ignore")
torch.manual_seed(42)
np.random.seed(42)

device = "mps" if hasattr(torch.backends, "mps") and torch.backends.mps.is_available() else \
         ("cuda" if torch.cuda.is_available() else "cpu")
print("✅ Device:", device)

# ============================================================
# OPTIMIZED CONFIGURATION FOR 33 FLARES
# ============================================================
DATA_DIR = "preprocessed_data"
IMG_CHANNELS = 13
IMG_SIZE = 256  # ← UPGRADED from 128 to 256
EPOCHS = 100    # ← INCREASED from 80
BATCH_SIZE = 2  # ← INCREASED from 1 (with 33 flares we can use batch=2)
LR = 3e-4       # ← REDUCED learning rate for stability
WEIGHT_DECAY = 1e-4
SCHED_STEP, SCHED_GAMMA = 25, 0.5  # ← Adjusted for longer training
TARGET_SCALE = 1e-4
LOSS_WEIGHTS = torch.tensor([0.5, 0.3, 0.2], dtype=torch.float32)  # ← More balanced

print(f"""
OPTIMIZED CONFIGURATION FOR 33 FLARES:
- Image Size: {IMG_SIZE}×{IMG_SIZE}
- Epochs: {EPOCHS}
- Batch Size: {BATCH_SIZE}
- Learning Rate: {LR}
- Scheduler: StepLR (step={SCHED_STEP}, gamma={SCHED_GAMMA})
""")
# Out:
# Torch: 2.8.0  | Numpy: 2.2.6  | Python: 3.11.13 (main, Jun  5 2025, 08:21:08) [Clang 14.0.6 ]
# ✅ Device: mps
#
# OPTIMIZED CONFIGURATION FOR 33 FLARES:
# - Image Size: 256×256
# - Epochs: 100
# - Batch Size: 2
# - Learning Rate: 0.0003
# - Scheduler: StepLR (step=25, gamma=0.5)

# %%
# %%
# ============================================================
# CELL 2: Load Dataset
# ============================================================
# NOTE: You need to regenerate your preprocessed data at 256×256!
# If you still have 128×128 data, this will fail

try:
    X = np.load(os.path.join(DATA_DIR, "X_aiahmi_256.npy"))  # 256×256 version
    Y = np.load(os.path.join(DATA_DIR, "Y_aiahmi_256.npy"))
    print(f"✅ Loaded 256×256 dataset → X: {X.shape}, Y: {Y.shape}")
except FileNotFoundError:
    print("⚠️  256×256 data not found, loading 128×128...")
    X = np.load(os.path.join(DATA_DIR, "X_aiahmi.npy"))
    Y = np.load(os.path.join(DATA_DIR, "Y_aiahmi.npy"))
    print(f"⚠️  Using 128×128 dataset → X: {X.shape}, Y: {Y.shape}")
    print("   Consider regenerating at 256×256 for better performance!")

# Zero-mean target scaling
Y_scaled = (Y - Y.mean(axis=0)) / TARGET_SCALE
print(f"Target scaling: Mean={Y.mean(axis=0)}, Scale={TARGET_SCALE}")

# Load flare IDs
flare_ids = pd.read_csv("flare_euv_targets_3day.csv")["flare_id"].tolist()
assert len(flare_ids) == len(X), f"Mismatch: {len(X)} samples vs {len(flare_ids)} flare IDs"
print(f"✅ Loaded {len(flare_ids)} flares")

# Print dataset statistics
print(f"\nDataset Statistics:")
print(f"  Min/Max irradiance: {Y.min():.2e} / {Y.max():.2e}")
print(f"  Mean ± Std: {Y.mean():.2e} ± {Y.std():.2e}")
# Out:
# ✅ Loaded 256×256 dataset → X: (33, 13, 256, 256), Y: (33, 3)
# Target scaling: Mean=[8.8646077e-05 8.8066365e-05 8.8103399e-05], Scale=0.0001
# ✅ Loaded 33 flares
#
# Dataset Statistics:
#   Min/Max irradiance: 6.04e-05 / 1.21e-04
#   Mean ± Std: 8.83e-05 ± 1.53e-05

# %%
# %%
# ============================================================
# CELL 3: Global Standardization + Dataset Class
# ============================================================
def compute_global_stats(X):
    """Compute per-channel mean and std across all samples"""
    C = X.shape[1]
    means = np.array([X[:, c].mean() for c in range(C)], dtype=np.float32)
    stds  = np.array([X[:, c].std() + 1e-6 for c in range(C)], dtype=np.float32)
    return means, stds

GLOBAL_MEAN, GLOBAL_STD = compute_global_stats(X)
print("✅ Global statistics computed")
print(f"   Channel means: {GLOBAL_MEAN[:3]}... (showing first 3)")
print(f"   Channel stds:  {GLOBAL_STD[:3]}... (showing first 3)")

class FlareDataset(Dataset):
    def __init__(self, X, Y, mean, std, augment=False):
        self.X = X.astype(np.float32)
        self.Y = Y.astype(np.float32)
        self.mean = mean.astype(np.float32)
        self.std = std.astype(np.float32)
        self.augment = augment
    
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        x = (self.X[idx] - self.mean[:, None, None]) / self.std[:, None, None]
        y = self.Y[idx]
        
        # Data augmentation for training (random flips)
        if self.augment and np.random.rand() > 0.5:
            x = np.flip(x, axis=1).copy()  # Horizontal flip
        if self.augment and np.random.rand() > 0.5:
            x = np.flip(x, axis=2).copy()  # Vertical flip
        
        return torch.tensor(x), torch.tensor(y)

print("✅ Dataset class ready (with augmentation support)")
# Out:
# ✅ Global statistics computed
#    Channel means: [0.41056433 0.49668843 0.7356721 ]... (showing first 3)
#    Channel stds:  [0.18767157 0.23753043 0.21912515]... (showing first 3)
# ✅ Dataset class ready (with augmentation support)

# %%
# %%
# ============================================================
# CELL 4: BASELINE CNN - Simple Lightweight Architecture
# ============================================================
class BaselineCNN(nn.Module):
    """
    Lightweight CNN baseline for EUV forecasting
    
    Architecture:
    - 5 convolutional blocks with progressive downsampling
    - BatchNorm + ReLU activation
    - No residual connections
    - No attention mechanisms
    - No pretrained weights
    - Designed for fair comparison with FlareEUV
    
    Parameters: ~530K (vs. 21.8M for ResNet-34)
    """
    def __init__(self, in_channels=13, out_features=3, dropout=0.3):
        super().__init__()
        
        # Input: 13×256×256
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels, 32, kernel_size=7, stride=2, padding=3),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        )  # Output: 32×64×64
        
        self.conv2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )  # Output: 64×32×32
        
        self.conv3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )  # Output: 128×16×16
        
        self.conv4 = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )  # Output: 256×8×8
        
        self.conv5 = nn.Sequential(
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True)
        )  # Output: 512×8×8
        
        # Global average pooling
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))  # Output: 512×1×1
        
        # Regression head (same as FlareEUV for fair comparison)
        self.fc = nn.Sequential(
            nn.Dropout(dropout),
            nn.Linear(512, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout / 2),
            nn.Linear(256, out_features)
        )
    
    def forward(self, x):
        # Forward pass through conv blocks
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)
        
        # Global pooling + regression
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.fc(x)
        
        return x


# Test model and count parameters
test_model = BaselineCNN()
total_params = sum(p.numel() for p in test_model.parameters())
trainable_params = sum(p.numel() for p in test_model.parameters() if p.requires_grad)

print("✅ BaselineCNN (Lightweight Architecture)")
print(f"   Total parameters: {total_params:,}")
print(f"   Trainable parameters: {trainable_params:,}")
print(f"   Architecture: 5-layer CNN with BatchNorm")
print(f"   No residual connections, no attention, no pretraining")

# Test forward pass
test_input = torch.randn(2, 13, 256, 256)  # Batch size 2
test_output = test_model(test_input)
print(f"\n✅ Forward pass test:")
print(f"   Input shape:  {test_input.shape}")
print(f"   Output shape: {test_output.shape}")

del test_model, test_input, test_output
# Out:
# ✅ BaselineCNN (Lightweight Architecture)
#    Total parameters: 1,722,179
#    Trainable parameters: 1,722,179
#    Architecture: 5-layer CNN with BatchNorm
#    No residual connections, no attention, no pretraining
#
# ✅ Forward pass test:
#    Input shape:  torch.Size([2, 13, 256, 256])
#    Output shape: torch.Size([2, 3])

# %%
# %%
# ============================================================
# CELL 5: Loss Function
# ============================================================
def loss_fn_weighted(pred, target, weights=LOSS_WEIGHTS):
    """Horizon-weighted MSE loss"""
    diff2 = (pred - target) ** 2
    weighted = diff2 * weights.to(pred.device)
    return weighted.mean()

print("✅ Weighted MSE loss function ready")
print(f"   Horizon weights: {LOSS_WEIGHTS.numpy()}")
# Out:
# ✅ Weighted MSE loss function ready
#    Horizon weights: [0.5 0.3 0.2]

# %%
# %%
# ============================================================
# CELL 6: Training Functions (OPTIMIZED)
# ============================================================
def train_one_epoch(model, loader, optimizer):
    """Train for one epoch with gradient clipping"""
    model.train()
    epoch_losses = []
    
    for xb, yb in loader:
        xb = xb.to(device, dtype=torch.float32)
        yb = yb.to(device, dtype=torch.float32)
        
        optimizer.zero_grad()
        pred = model(xb)
        loss = loss_fn_weighted(pred, yb)
        loss.backward()
        
        # Gradient clipping for stability
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        optimizer.step()
        epoch_losses.append(loss.item())
    
    return np.mean(epoch_losses)


def validate_epoch(model, loader):
    """Validate without gradient computation"""
    model.eval()
    val_losses = []
    
    with torch.no_grad():
        for xb, yb in loader:
            xb = xb.to(device, dtype=torch.float32)
            yb = yb.to(device, dtype=torch.float32)
            
            pred = model(xb)
            loss = loss_fn_weighted(pred, yb)
            val_losses.append(loss.item())
    
    return np.mean(val_losses)


def train_with_validation(model, train_loader, val_loader, epochs=EPOCHS, patience=50):
    """
    Train with validation-based early stopping
    OPTIMIZED FOR 33 FLARES
    """
    model = model.to(device, dtype=torch.float32)
    
    # Optimizer with weight decay
    optimizer = torch.optim.AdamW(
        model.parameters(), 
        lr=LR, 
        weight_decay=WEIGHT_DECAY,
        betas=(0.9, 0.999)
    )
    
    # Cosine annealing with warm restarts (better than StepLR)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
        optimizer, 
        T_0=20,  # Restart every 20 epochs
        T_mult=2  # Double restart interval each time
    )
    
    best_val_loss = float("inf")
    best_state = None
    patience_counter = 0
    
    print(f"   Training for up to {epochs} epochs (patience={patience})...")
    
    for ep in range(epochs):
        # Train
        train_loss = train_one_epoch(model, train_loader, optimizer)
        
        # Validate
        val_loss = validate_epoch(model, val_loader)
        
        # Step scheduler
        scheduler.step()
        
        # Get current learning rate
        current_lr = optimizer.param_groups[0]['lr']
        
        # Print progress
        if ep % 10 == 0 or ep == epochs - 1:
            print(f"   Epoch {ep:03d}/{epochs} | Train={train_loss:.6f} | Val={val_loss:.6f} | LR={current_lr:.2e}")
        
        # Early stopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"   ⏹️  Early stopping at epoch {ep} (best val={best_val_loss:.6f})")
                break
    
    # Load best model
    if best_state is not None:
        model.load_state_dict(best_state)
        print(f"   ✅ Loaded best model (val loss: {best_val_loss:.6f})")
    
    return model

print("✅ Training functions ready")
# Out:
# ✅ Training functions ready

# %%
# %%
# ============================================================
# CELL 7: Evaluation Function (FIXED)
# ============================================================
def evaluate(model, loader):
    """
    Comprehensive evaluation with multiple metrics
    FIXED: Handles single-sample test sets (LOFO)
    """
    model.eval()
    preds, trues = [], []
    
    with torch.no_grad():
        for xb, yb in loader:
            xb = xb.to(device, dtype=torch.float32)
            yb = yb.to(device, dtype=torch.float32)
            p = model(xb)
            preds.extend(p.cpu().numpy())
            trues.extend(yb.cpu().numpy())
    
    # Denormalize
    preds = np.array(preds) * TARGET_SCALE + Y.mean(axis=0)
    trues = np.array(trues) * TARGET_SCALE + Y.mean(axis=0)
    
    # Flatten for global metrics
    preds_flat = preds.ravel()
    trues_flat = trues.ravel()
    
    # Global metrics (across all horizons)
    mae = mean_absolute_error(trues_flat, preds_flat)
    
    # Pearson correlation - handle single sample case
    if len(trues_flat) >= 2:
        r, p_value = pearsonr(trues_flat, preds_flat)
        r2 = r2_score(trues_flat, preds_flat)
    else:
        # For single sample, use absolute error as proxy
        r = np.nan
        p_value = np.nan
        r2 = np.nan
    
    # Per-horizon metrics
    mae_per_horizon = []
    r_per_horizon = []
    
    for i in range(3):
        # MAE per horizon (always computable)
        mae_h = mean_absolute_error(trues[:, i], preds[:, i])
        mae_per_horizon.append(mae_h)
        
        # Correlation per horizon (requires 2+ samples)
        if len(trues[:, i]) >= 2:
            r_h, _ = pearsonr(trues[:, i], preds[:, i])
            r_per_horizon.append(r_h)
        else:
            r_per_horizon.append(np.nan)
    
    return {
        'mae': mae,
        'r': r,
        'r2': r2,
        'p_value': p_value,
        'preds': preds,
        'trues': trues,
        'mae_per_horizon': mae_per_horizon,
        'r_per_horizon': r_per_horizon
    }

print("✅ Evaluation function ready (handles single-sample LOFO)")
# Out:
# ✅ Evaluation function ready (handles single-sample LOFO)

# %%
# %%
# ============================================================
# CELL 8: LOFO CROSS-VALIDATION - BASELINE CNN
# ============================================================
import csv

os.makedirs("results_lofo_baseline_cnn", exist_ok=True)  # ← CHANGED
results = []

print("\n" + "="*70)
print("LOFO CROSS-VALIDATION - BASELINE CNN")  # ← CHANGED
print("="*70)
print(f"Total flares: {len(flare_ids)}")
print(f"Train/Val/Test split: {len(flare_ids)-2} / 1 / 1 per fold")
print("="*70)

total_start_time = time.time()

for test_idx, test_flare in enumerate(flare_ids):
    fold_start_time = time.time()
    
    print(f"\n{'='*70}")
    print(f"FOLD {test_idx + 1}/{len(flare_ids)} | Test: {test_flare}")
    print(f"{'='*70}")
    
    # Create masks
    test_mask = np.zeros(len(X), dtype=bool)
    test_mask[test_idx] = True

    train_indices = np.where(~test_mask)[0]
    val_idx = train_indices[test_idx % len(train_indices)]
    
    val_mask = np.zeros(len(X), dtype=bool)
    val_mask[val_idx] = True
    train_mask = ~test_mask & ~val_mask
    
    print(f"   Train: {np.sum(train_mask)} flares")
    print(f"   Val: {flare_ids[val_idx]}")
    print(f"   Test: {test_flare}")

    # Compute mean/std ONLY on training set (no leakage!)
    train_mean, train_std = compute_global_stats(X[train_mask])

    # Create datasets using TRAIN NORMALIZATION ONLY
    ds_train = FlareDataset(X[train_mask], Y_scaled[train_mask],
                            train_mean, train_std, augment=True)
    ds_val = FlareDataset(X[val_mask], Y_scaled[val_mask],
                          train_mean, train_std, augment=False)
    ds_test = FlareDataset(X[test_mask], Y_scaled[test_mask],
                           train_mean, train_std, augment=False)

    train_loader = DataLoader(ds_train, batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(ds_val, batch_size=1, shuffle=False)
    test_loader = DataLoader(ds_test, batch_size=1, shuffle=False)

    # Initialize model
    model = BaselineCNN(in_channels=IMG_CHANNELS, out_features=3, dropout=0.3)  # ← CHANGED

    # Train
    model = train_with_validation(model, train_loader, val_loader,
                                  epochs=EPOCHS, patience=50)

    # Save model
    model_path = f"results_lofo_baseline_cnn/{test_flare}_model.pth"  # ← CHANGED
    torch.save(model.state_dict(), model_path)

    # Evaluate
    metrics = evaluate(model, test_loader)
    results.append((test_flare, metrics))

    # Save predictions
    np.savez(f"results_lofo_baseline_cnn/{test_flare}_preds.npz",  # ← CHANGED
             flare=test_flare,
             preds=metrics['preds'],
             trues=metrics['trues'])

    fold_time = time.time() - fold_start_time

    print(f"\n   📊 Test Metrics:")
    print(f"      MAE: {metrics['mae']:.6e}")
    print(f"      Pearson r: {metrics['r']:.3f} (p={metrics['p_value']:.3e})")
    print(f"      R²: {metrics['r2']:.3f}")
    print(f"      Horizon MAE: T0={metrics['mae_per_horizon'][0]:.2e}, " +
          f"T1={metrics['mae_per_horizon'][1]:.2e}, T2={metrics['mae_per_horizon'][2]:.2e}")
    print(f"   ⏱️  Fold time: {fold_time/60:.1f} minutes")


# ============================================================
# FINAL SUMMARY AND RESULTS
# ============================================================
total_time = time.time() - total_start_time

print("\n" + "="*70)
print("LOFO COMPLETE - BASELINE CNN")  # ← CHANGED
print("="*70)
print(f"Total time: {total_time/60:.1f} minutes ({total_time/3600:.1f} hours)")
print(f"Avg per fold: {total_time/len(flare_ids)/60:.1f} minutes\n")

all_maes = [m['mae'] for _, m in results]
all_r2s = [m['r2'] for _, m in results if not np.isnan(m['r2'])]

print("SUMMARY STATISTICS:")
print(f"  MAE: {np.mean(all_maes):.6e} ± {np.std(all_maes):.6e}")
print(f"  R² (valid): {np.mean(all_r2s):.3f} ± {np.std(all_r2s):.3f}")

# Save summary
with open("results_lofo_baseline_cnn/summary.csv", "w", newline="") as f:  # ← CHANGED
    w = csv.writer(f)
    w.writerow(["flare_id", "MAE", "MAE_T0", "MAE_T1", "MAE_T2"])
    for fid, m in results:
        w.writerow([
            fid,
            f"{m['mae']:.6e}",
            f"{m['mae_per_horizon'][0]:.6e}",
            f"{m['mae_per_horizon'][1]:.6e}",
            f"{m['mae_per_horizon'][2]:.6e}"
        ])

print("✅ Results saved to results_lofo_baseline_cnn/")  # ← CHANGED
# Out:
# ======================================================================
# LOFO CROSS-VALIDATION - BASELINE CNN
# ======================================================================
# Total flares: 33
# Train/Val/Test split: 31 / 1 / 1 per fold
# ======================================================================
#
# ======================================================================
# FOLD 1/33 | Test: AR11158_M6.6
# ======================================================================
#    Train: 31 flares
#    Val: AR11158_X2.2
#    Test: AR11158_M6.6
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.010572 | Val=0.007705 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004438 | Val=0.000532 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004270 | Val=0.051966 | LR=3.00e-04
#    Epoch 030/100 | Train=0.002542 | Val=0.005675 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002540 | Val=0.005838 | LR=1.38e-04
#    Epoch 050/100 | Train=0.003080 | Val=0.006303 | LR=3.59e-05
#    Epoch 060/100 | Train=0.001445 | Val=0.003608 | LR=3.00e-04
#    Epoch 070/100 | Train=0.001992 | Val=0.002692 | LR=2.86e-04
#    Epoch 080/100 | Train=0.001778 | Val=0.016477 | LR=2.52e-04
#    Epoch 090/100 | Train=0.001392 | Val=0.001618 | LR=2.02e-04
#    ⏹️  Early stopping at epoch 96 (best val=0.000044)
#    ✅ Loaded best model (val loss: 0.000044)
#
#    📊 Test Metrics:
#       MAE: 1.785670e-06
#       Pearson r: 0.819 (p=3.893e-01)
#       R²: -2.045
#       Horizon MAE: T0=2.18e-06, T1=1.42e-07, T2=3.03e-06
#    ⏱️  Fold time: 0.6 minutes
#
# ======================================================================
# FOLD 2/33 | Test: AR11158_X2.2
# ======================================================================
#    Train: 31 flares
#    Val: AR11261_M9.3
#    Test: AR11158_X2.2
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.010741 | Val=0.014478 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004843 | Val=0.008710 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004331 | Val=0.009927 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003658 | Val=0.044673 | LR=2.47e-04
#    Epoch 040/100 | Train=0.003805 | Val=0.004854 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001770 | Val=0.004601 | LR=3.59e-05
#    Epoch 060/100 | Train=0.002253 | Val=0.003540 | LR=3.00e-04
#    ⏹️  Early stopping at epoch 64 (best val=0.000113)
#    ✅ Loaded best model (val loss: 0.000113)
#
#    📊 Test Metrics:
#       MAE: 6.238207e-06
#       Pearson r: 0.064 (p=9.590e-01)
#       R²: -30.569
#       Horizon MAE: T0=9.49e-06, T1=3.87e-06, T2=5.35e-06
#    ⏱️  Fold time: 0.4 minutes
#
# ======================================================================
# FOLD 3/33 | Test: AR11261_M9.3
# ======================================================================
#    Train: 31 flares
#    Val: AR11429_X5.4
#    Test: AR11261_M9.3
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.008569 | Val=0.010932 | LR=2.98e-04
#    Epoch 010/100 | Train=0.007042 | Val=0.009931 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004869 | Val=0.000575 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003008 | Val=0.003221 | LR=2.47e-04
#    Epoch 040/100 | Train=0.004790 | Val=0.001847 | LR=1.38e-04
#    Epoch 050/100 | Train=0.002751 | Val=0.000086 | LR=3.59e-05
#    Epoch 060/100 | Train=0.003665 | Val=0.001592 | LR=3.00e-04
#    Epoch 070/100 | Train=0.001930 | Val=0.003915 | LR=2.86e-04
#    Epoch 080/100 | Train=0.002831 | Val=0.000175 | LR=2.52e-04
#    Epoch 090/100 | Train=0.001777 | Val=0.000148 | LR=2.02e-04
#    Epoch 099/100 | Train=0.001899 | Val=0.000610 | LR=1.50e-04
#    ✅ Loaded best model (val loss: 0.000021)
#
#    📊 Test Metrics:
#       MAE: 2.647073e-06
#       Pearson r: 0.052 (p=9.670e-01)
#       R²: -1.664
#       Horizon MAE: T0=5.52e-06, T1=2.13e-06, T2=2.89e-07
#    ⏱️  Fold time: 0.6 minutes
#
# ======================================================================
# FOLD 4/33 | Test: AR11429_X5.4
# ======================================================================
#    Train: 31 flares
#    Val: AR11429_M6.3
#    Test: AR11429_X5.4
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.010030 | Val=0.004517 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004387 | Val=0.000296 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004889 | Val=0.000132 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003985 | Val=0.008822 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002327 | Val=0.000445 | LR=1.38e-04
#    Epoch 050/100 | Train=0.002486 | Val=0.000537 | LR=3.59e-05
#    Epoch 060/100 | Train=0.002135 | Val=0.000245 | LR=3.00e-04
#    Epoch 070/100 | Train=0.004748 | Val=0.000381 | LR=2.86e-04
#    Epoch 080/100 | Train=0.005139 | Val=0.000177 | LR=2.52e-04
#    Epoch 090/100 | Train=0.002728 | Val=0.003909 | LR=2.02e-04
#    Epoch 099/100 | Train=0.001538 | Val=0.001620 | LR=1.50e-04
#    ✅ Loaded best model (val loss: 0.000069)
#
#    📊 Test Metrics:
#       MAE: 5.023030e-06
#       Pearson r: -1.000 (p=1.850e-02)
#       R²: -9.312
#       Horizon MAE: T0=6.88e-06, T1=2.85e-06, T2=5.34e-06
#    ⏱️  Fold time: 0.6 minutes
#
# ======================================================================
# FOLD 5/33 | Test: AR11429_M6.3
# ======================================================================
#    Train: 31 flares
#    Val: AR11520_X1.4
#    Test: AR11429_M6.3
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.010751 | Val=0.001088 | LR=2.98e-04
#    Epoch 010/100 | Train=0.003971 | Val=0.003609 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004963 | Val=0.002318 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003757 | Val=0.000628 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002476 | Val=0.002633 | LR=1.38e-04
#    Epoch 050/100 | Train=0.004570 | Val=0.001901 | LR=3.59e-05
#    Epoch 060/100 | Train=0.002728 | Val=0.000911 | LR=3.00e-04
#    Epoch 070/100 | Train=0.002192 | Val=0.000488 | LR=2.86e-04
#    ⏹️  Early stopping at epoch 76 (best val=0.000059)
#    ✅ Loaded best model (val loss: 0.000059)
#
#    📊 Test Metrics:
#       MAE: 1.392070e-05
#       Pearson r: -0.488 (p=6.758e-01)
#       R²: -81.667
#       Horizon MAE: T0=1.17e-05, T1=1.75e-05, T2=1.26e-05
#    ⏱️  Fold time: 0.5 minutes
#
# ======================================================================
# FOLD 6/33 | Test: AR11520_X1.4
# ======================================================================
#    Train: 31 flares
#    Val: AR11719_M6.5
#    Test: AR11520_X1.4
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.010220 | Val=0.006612 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004540 | Val=0.000166 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004902 | Val=0.000112 | LR=3.00e-04
#    Epoch 030/100 | Train=0.002090 | Val=0.000143 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002001 | Val=0.000242 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001549 | Val=0.000435 | LR=3.59e-05
#    Epoch 060/100 | Train=0.001827 | Val=0.002814 | LR=3.00e-04
#    Epoch 070/100 | Train=0.002762 | Val=0.000124 | LR=2.86e-04
#    ⏹️  Early stopping at epoch 72 (best val=0.000054)
#    ✅ Loaded best model (val loss: 0.000054)
#
#    📊 Test Metrics:
#       MAE: 2.837643e-06
#       Pearson r: 0.695 (p=5.104e-01)
#       R²: -0.410
#       Horizon MAE: T0=5.59e-08, T1=5.56e-06, T2=2.90e-06
#    ⏱️  Fold time: 0.4 minutes
#
# ======================================================================
# FOLD 7/33 | Test: AR11719_M6.5
# ======================================================================
#    Train: 31 flares
#    Val: AR12036_M7.3
#    Test: AR11719_M6.5
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.008853 | Val=0.025405 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004588 | Val=0.006896 | LR=1.27e-04
#    Epoch 020/100 | Train=0.005262 | Val=0.003730 | LR=3.00e-04
#    Epoch 030/100 | Train=0.006040 | Val=0.002373 | LR=2.47e-04
#    Epoch 040/100 | Train=0.003211 | Val=0.000228 | LR=1.38e-04
#    Epoch 050/100 | Train=0.003030 | Val=0.001086 | LR=3.59e-05
#    Epoch 060/100 | Train=0.003894 | Val=0.000136 | LR=3.00e-04
#    Epoch 070/100 | Train=0.004231 | Val=0.008613 | LR=2.86e-04
#    Epoch 080/100 | Train=0.002519 | Val=0.001236 | LR=2.52e-04
#    Epoch 090/100 | Train=0.001670 | Val=0.000228 | LR=2.02e-04
#    Epoch 099/100 | Train=0.002059 | Val=0.000173 | LR=1.50e-04
#    ✅ Loaded best model (val loss: 0.000040)
#
#    📊 Test Metrics:
#       MAE: 2.417507e-06
#       Pearson r: -0.965 (p=1.700e-01)
#       R²: -0.404
#       Horizon MAE: T0=1.46e-06, T1=1.73e-07, T2=5.62e-06
#    ⏱️  Fold time: 0.6 minutes
#
# ======================================================================
# FOLD 8/33 | Test: AR12036_M7.3
# ======================================================================
#    Train: 31 flares
#    Val: AR11944_X1.2
#    Test: AR12036_M7.3
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.011798 | Val=0.016473 | LR=2.98e-04
#    Epoch 010/100 | Train=0.006298 | Val=0.000426 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004359 | Val=0.000532 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003465 | Val=0.003380 | LR=2.47e-04
#    Epoch 040/100 | Train=0.003153 | Val=0.000423 | LR=1.38e-04
#    Epoch 050/100 | Train=0.002946 | Val=0.007616 | LR=3.59e-05
#    Epoch 060/100 | Train=0.005203 | Val=0.010723 | LR=3.00e-04
#    Epoch 070/100 | Train=0.003035 | Val=0.028038 | LR=2.86e-04
#    Epoch 080/100 | Train=0.002974 | Val=0.000242 | LR=2.52e-04
#    ⏹️  Early stopping at epoch 84 (best val=0.000125)
#    ✅ Loaded best model (val loss: 0.000125)
#
#    📊 Test Metrics:
#       MAE: 5.503811e-06
#       Pearson r: -0.990 (p=9.226e-02)
#       R²: -65.736
#       Horizon MAE: T0=8.68e-06, T1=7.26e-06, T2=5.74e-07
#    ⏱️  Fold time: 0.5 minutes
#
# ======================================================================
# FOLD 9/33 | Test: AR11944_X1.2
# ======================================================================
#    Train: 31 flares
#    Val: AR12017_X1.0
#    Test: AR11944_X1.2
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.011986 | Val=0.008061 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004478 | Val=0.011275 | LR=1.27e-04
#    Epoch 020/100 | Train=0.003555 | Val=0.015761 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003339 | Val=0.000404 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002776 | Val=0.000134 | LR=1.38e-04
#    Epoch 050/100 | Train=0.002174 | Val=0.000920 | LR=3.59e-05
#    Epoch 060/100 | Train=0.003263 | Val=0.002234 | LR=3.00e-04
#    Epoch 070/100 | Train=0.005016 | Val=0.033829 | LR=2.86e-04
#    Epoch 080/100 | Train=0.002941 | Val=0.000235 | LR=2.52e-04
#    Epoch 090/100 | Train=0.003097 | Val=0.003173 | LR=2.02e-04
#    Epoch 099/100 | Train=0.002528 | Val=0.000012 | LR=1.50e-04
#    ✅ Loaded best model (val loss: 0.000008)
#
#    📊 Test Metrics:
#       MAE: 1.302426e-05
#       Pearson r: -0.933 (p=2.337e-01)
#       R²: -23.647
#       Horizon MAE: T0=8.57e-06, T1=1.40e-05, T2=1.65e-05
#    ⏱️  Fold time: 0.6 minutes
#
# ======================================================================
# FOLD 10/33 | Test: AR12017_X1.0
# ======================================================================
#    Train: 31 flares
#    Val: AR11166_X1.5
#    Test: AR12017_X1.0
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.010065 | Val=0.000206 | LR=2.98e-04
#    Epoch 010/100 | Train=0.003207 | Val=0.005863 | LR=1.27e-04
#    Epoch 020/100 | Train=0.002919 | Val=0.004465 | LR=3.00e-04
#    Epoch 030/100 | Train=0.005493 | Val=0.002041 | LR=2.47e-04
#    Epoch 040/100 | Train=0.003926 | Val=0.002022 | LR=1.38e-04
#    Epoch 050/100 | Train=0.002694 | Val=0.000061 | LR=3.59e-05
#    Epoch 060/100 | Train=0.003519 | Val=0.007326 | LR=3.00e-04
#    Epoch 070/100 | Train=0.003236 | Val=0.012510 | LR=2.86e-04
#    Epoch 080/100 | Train=0.001769 | Val=0.000272 | LR=2.52e-04
#    Epoch 090/100 | Train=0.002848 | Val=0.001033 | LR=2.02e-04
#    Epoch 099/100 | Train=0.001935 | Val=0.016921 | LR=1.50e-04
#    ✅ Loaded best model (val loss: 0.000061)
#
#    📊 Test Metrics:
#       MAE: 8.302864e-06
#       Pearson r: 0.583 (p=6.037e-01)
#       R²: -55.646
#       Horizon MAE: T0=8.16e-06, T1=1.30e-05, T2=3.76e-06
#    ⏱️  Fold time: 0.6 minutes
#
# ======================================================================
# FOLD 11/33 | Test: AR11166_X1.5
# ======================================================================
#    Train: 31 flares
#    Val: AR11261_M6.0
#    Test: AR11166_X1.5
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.011716 | Val=0.028810 | LR=2.98e-04
#    Epoch 010/100 | Train=0.008173 | Val=0.000736 | LR=1.27e-04
#    Epoch 020/100 | Train=0.005624 | Val=0.000320 | LR=3.00e-04
#    Epoch 030/100 | Train=0.005619 | Val=0.004753 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002941 | Val=0.003558 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001838 | Val=0.006309 | LR=3.59e-05
#    Epoch 060/100 | Train=0.002471 | Val=0.001217 | LR=3.00e-04
#    ⏹️  Early stopping at epoch 64 (best val=0.000055)
#    ✅ Loaded best model (val loss: 0.000055)
#
#    📊 Test Metrics:
#       MAE: 2.951839e-06
#       Pearson r: 0.860 (p=3.406e-01)
#       R²: -0.504
#       Horizon MAE: T0=4.72e-06, T1=2.90e-06, T2=1.24e-06
#    ⏱️  Fold time: 0.4 minutes
#
# ======================================================================
# FOLD 12/33 | Test: AR11261_M6.0
# ======================================================================
#    Train: 31 flares
#    Val: AR11261_M9.3b
#    Test: AR11261_M6.0
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.008631 | Val=0.024565 | LR=2.98e-04
#    Epoch 010/100 | Train=0.006348 | Val=0.001322 | LR=1.27e-04
#    Epoch 020/100 | Train=0.002652 | Val=0.001268 | LR=3.00e-04
#    Epoch 030/100 | Train=0.004254 | Val=0.003354 | LR=2.47e-04
#    Epoch 040/100 | Train=0.004151 | Val=0.001005 | LR=1.38e-04
#    Epoch 050/100 | Train=0.002137 | Val=0.000139 | LR=3.59e-05
#    Epoch 060/100 | Train=0.003394 | Val=0.004000 | LR=3.00e-04
#    ⏹️  Early stopping at epoch 66 (best val=0.000032)
#    ✅ Loaded best model (val loss: 0.000032)
#
#    📊 Test Metrics:
#       MAE: 4.961830e-06
#       Pearson r: 0.392 (p=7.433e-01)
#       R²: -69.956
#       Horizon MAE: T0=6.56e-06, T1=3.60e-06, T2=4.73e-06
#    ⏱️  Fold time: 0.4 minutes
#
# ======================================================================
# FOLD 13/33 | Test: AR11261_M9.3b
# ======================================================================
#    Train: 31 flares
#    Val: AR11283_M5.3
#    Test: AR11261_M9.3b
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.012134 | Val=0.017828 | LR=2.98e-04
#    Epoch 010/100 | Train=0.006205 | Val=0.001801 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004997 | Val=0.003504 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003794 | Val=0.022361 | LR=2.47e-04
#    Epoch 040/100 | Train=0.003464 | Val=0.003236 | LR=1.38e-04
#    Epoch 050/100 | Train=0.002233 | Val=0.000366 | LR=3.59e-05
#    Epoch 060/100 | Train=0.002130 | Val=0.000354 | LR=3.00e-04
#    Epoch 070/100 | Train=0.002860 | Val=0.041411 | LR=2.86e-04
#    ⏹️  Early stopping at epoch 78 (best val=0.000037)
#    ✅ Loaded best model (val loss: 0.000037)
#
#    📊 Test Metrics:
#       MAE: 4.289536e-06
#       Pearson r: -0.602 (p=5.889e-01)
#       R²: -15.833
#       Horizon MAE: T0=7.47e-07, T1=5.99e-06, T2=6.13e-06
#    ⏱️  Fold time: 0.5 minutes
#
# ======================================================================
# FOLD 14/33 | Test: AR11283_M5.3
# ======================================================================
#    Train: 31 flares
#    Val: AR11283_X2.1
#    Test: AR11283_M5.3
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.012677 | Val=0.008225 | LR=2.98e-04
#    Epoch 010/100 | Train=0.006361 | Val=0.001600 | LR=1.27e-04
#    Epoch 020/100 | Train=0.008543 | Val=0.001773 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003786 | Val=0.000473 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002295 | Val=0.000324 | LR=1.38e-04
#    Epoch 050/100 | Train=0.002969 | Val=0.000591 | LR=3.59e-05
#    Epoch 060/100 | Train=0.003398 | Val=0.000149 | LR=3.00e-04
#    Epoch 070/100 | Train=0.004833 | Val=0.004246 | LR=2.86e-04
#    Epoch 080/100 | Train=0.001762 | Val=0.002563 | LR=2.52e-04
#    Epoch 090/100 | Train=0.004088 | Val=0.000775 | LR=2.02e-04
#    Epoch 099/100 | Train=0.002653 | Val=0.000362 | LR=1.50e-04
#    ✅ Loaded best model (val loss: 0.000149)
#
#    📊 Test Metrics:
#       MAE: 3.647018e-06
#       Pearson r: 0.267 (p=8.276e-01)
#       R²: -1.843
#       Horizon MAE: T0=1.79e-07, T1=4.57e-06, T2=6.19e-06
#    ⏱️  Fold time: 0.6 minutes
#
# ======================================================================
# FOLD 15/33 | Test: AR11283_X2.1
# ======================================================================
#    Train: 31 flares
#    Val: AR11283_X1.8
#    Test: AR11283_X2.1
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.010445 | Val=0.000378 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004066 | Val=0.000315 | LR=1.27e-04
#    Epoch 020/100 | Train=0.005247 | Val=0.002810 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003169 | Val=0.002486 | LR=2.47e-04
#    Epoch 040/100 | Train=0.003140 | Val=0.005060 | LR=1.38e-04
#    Epoch 050/100 | Train=0.002167 | Val=0.000636 | LR=3.59e-05
#    Epoch 060/100 | Train=0.002762 | Val=0.002494 | LR=3.00e-04
#    Epoch 070/100 | Train=0.004699 | Val=0.000178 | LR=2.86e-04
#    Epoch 080/100 | Train=0.003721 | Val=0.000100 | LR=2.52e-04
#    Epoch 090/100 | Train=0.001812 | Val=0.000115 | LR=2.02e-04
#    Epoch 099/100 | Train=0.002002 | Val=0.000129 | LR=1.50e-04
#    ✅ Loaded best model (val loss: 0.000015)
#
#    📊 Test Metrics:
#       MAE: 7.323780e-06
#       Pearson r: 0.741 (p=4.683e-01)
#       R²: -7.217
#       Horizon MAE: T0=6.06e-06, T1=5.96e-06, T2=9.95e-06
#    ⏱️  Fold time: 0.6 minutes
#
# ======================================================================
# FOLD 16/33 | Test: AR11283_X1.8
# ======================================================================
#    Train: 31 flares
#    Val: AR11283_M6.7
#    Test: AR11283_X1.8
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.011281 | Val=0.006756 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004711 | Val=0.003916 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004191 | Val=0.001000 | LR=3.00e-04
#    Epoch 030/100 | Train=0.004491 | Val=0.002828 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002777 | Val=0.003760 | LR=1.38e-04
#    Epoch 050/100 | Train=0.003721 | Val=0.000124 | LR=3.59e-05
#    Epoch 060/100 | Train=0.002734 | Val=0.009321 | LR=3.00e-04
#    Epoch 070/100 | Train=0.003775 | Val=0.000170 | LR=2.86e-04
#    Epoch 080/100 | Train=0.003054 | Val=0.000045 | LR=2.52e-04
#    Epoch 090/100 | Train=0.001780 | Val=0.004683 | LR=2.02e-04
#    Epoch 099/100 | Train=0.001440 | Val=0.003128 | LR=1.50e-04
#    ✅ Loaded best model (val loss: 0.000040)
#
#    📊 Test Metrics:
#       MAE: 1.913395e-06
#       Pearson r: -0.485 (p=6.777e-01)
#       R²: -1.245
#       Horizon MAE: T0=3.12e-06, T1=9.17e-07, T2=1.70e-06
#    ⏱️  Fold time: 0.6 minutes
#
# ======================================================================
# FOLD 17/33 | Test: AR11283_M6.7
# ======================================================================
#    Train: 31 flares
#    Val: AR11302_M7.4
#    Test: AR11283_M6.7
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.010658 | Val=0.005391 | LR=2.98e-04
#    Epoch 010/100 | Train=0.002684 | Val=0.001226 | LR=1.27e-04
#    Epoch 020/100 | Train=0.005675 | Val=0.002974 | LR=3.00e-04
#    Epoch 030/100 | Train=0.007212 | Val=0.000522 | LR=2.47e-04
#    Epoch 040/100 | Train=0.003324 | Val=0.001361 | LR=1.38e-04
#    Epoch 050/100 | Train=0.003145 | Val=0.001530 | LR=3.59e-05
#    Epoch 060/100 | Train=0.002276 | Val=0.001401 | LR=3.00e-04
#    Epoch 070/100 | Train=0.003754 | Val=0.000659 | LR=2.86e-04
#    ⏹️  Early stopping at epoch 78 (best val=0.000366)
#    ✅ Loaded best model (val loss: 0.000366)
#
#    📊 Test Metrics:
#       MAE: 1.248133e-05
#       Pearson r: -0.812 (p=3.963e-01)
#       R²: -45.639
#       Horizon MAE: T0=1.67e-05, T1=1.25e-05, T2=8.20e-06
#    ⏱️  Fold time: 0.5 minutes
#
# ======================================================================
# FOLD 18/33 | Test: AR11302_M7.4
# ======================================================================
#    Train: 31 flares
#    Val: AR11402_M8.7
#    Test: AR11302_M7.4
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.017160 | Val=0.001370 | LR=2.98e-04
#    Epoch 010/100 | Train=0.003265 | Val=0.002616 | LR=1.27e-04
#    Epoch 020/100 | Train=0.006427 | Val=0.003716 | LR=3.00e-04
#    Epoch 030/100 | Train=0.005717 | Val=0.000136 | LR=2.47e-04
#    Epoch 040/100 | Train=0.003439 | Val=0.000331 | LR=1.38e-04
#    Epoch 050/100 | Train=0.002626 | Val=0.000080 | LR=3.59e-05
#    Epoch 060/100 | Train=0.003543 | Val=0.000105 | LR=3.00e-04
#    Epoch 070/100 | Train=0.003011 | Val=0.000060 | LR=2.86e-04
#    Epoch 080/100 | Train=0.001555 | Val=0.000635 | LR=2.52e-04
#    Epoch 090/100 | Train=0.001529 | Val=0.000080 | LR=2.02e-04
#    Epoch 099/100 | Train=0.001362 | Val=0.000361 | LR=1.50e-04
#    ✅ Loaded best model (val loss: 0.000018)
#
#    📊 Test Metrics:
#       MAE: 1.260135e-05
#       Pearson r: -0.341 (p=7.788e-01)
#       R²: -5.667
#       Horizon MAE: T0=5.97e-06, T1=1.23e-05, T2=1.95e-05
#    ⏱️  Fold time: 0.6 minutes
#
# ======================================================================
# FOLD 19/33 | Test: AR11402_M8.7
# ======================================================================
#    Train: 31 flares
#    Val: AR11429_X1.3
#    Test: AR11402_M8.7
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.010336 | Val=0.001995 | LR=2.98e-04
#    Epoch 010/100 | Train=0.005178 | Val=0.000780 | LR=1.27e-04
#    Epoch 020/100 | Train=0.007199 | Val=0.001391 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003648 | Val=0.002866 | LR=2.47e-04
#    Epoch 040/100 | Train=0.003453 | Val=0.000922 | LR=1.38e-04
#    Epoch 050/100 | Train=0.002681 | Val=0.001088 | LR=3.59e-05
#    Epoch 060/100 | Train=0.003552 | Val=0.000144 | LR=3.00e-04
#    Epoch 070/100 | Train=0.004290 | Val=0.004599 | LR=2.86e-04
#    ⏹️  Early stopping at epoch 71 (best val=0.000066)
#    ✅ Loaded best model (val loss: 0.000066)
#
#    📊 Test Metrics:
#       MAE: 4.137124e-06
#       Pearson r: 0.698 (p=5.081e-01)
#       R²: -42.508
#       Horizon MAE: T0=2.94e-06, T1=2.58e-06, T2=6.89e-06
#    ⏱️  Fold time: 0.4 minutes
#
# ======================================================================
# FOLD 20/33 | Test: AR11429_X1.3
# ======================================================================
#    Train: 31 flares
#    Val: AR11429_M8.4
#    Test: AR11429_X1.3
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.015253 | Val=0.002820 | LR=2.98e-04
#    Epoch 010/100 | Train=0.006777 | Val=0.003431 | LR=1.27e-04
#    Epoch 020/100 | Train=0.003544 | Val=0.004316 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003931 | Val=0.001649 | LR=2.47e-04
#    Epoch 040/100 | Train=0.004790 | Val=0.000140 | LR=1.38e-04
#    Epoch 050/100 | Train=0.002263 | Val=0.000910 | LR=3.59e-05
#    ⏹️  Early stopping at epoch 58 (best val=0.000038)
#    ✅ Loaded best model (val loss: 0.000038)
#
#    📊 Test Metrics:
#       MAE: 1.182048e-05
#       Pearson r: 0.813 (p=3.961e-01)
#       R²: -50.841
#       Horizon MAE: T0=1.16e-05, T1=1.08e-05, T2=1.31e-05
#    ⏱️  Fold time: 0.4 minutes
#
# ======================================================================
# FOLD 21/33 | Test: AR11429_M8.4
# ======================================================================
#    Train: 31 flares
#    Val: AR11476_M5.7
#    Test: AR11429_M8.4
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.011296 | Val=0.000535 | LR=2.98e-04
#    Epoch 010/100 | Train=0.005331 | Val=0.000079 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004821 | Val=0.000041 | LR=3.00e-04
#    Epoch 030/100 | Train=0.004274 | Val=0.000183 | LR=2.47e-04
#    Epoch 040/100 | Train=0.004138 | Val=0.000057 | LR=1.38e-04
#    Epoch 050/100 | Train=0.002246 | Val=0.000047 | LR=3.59e-05
#    Epoch 060/100 | Train=0.002833 | Val=0.000556 | LR=3.00e-04
#    Epoch 070/100 | Train=0.004709 | Val=0.000067 | LR=2.86e-04
#    Epoch 080/100 | Train=0.002428 | Val=0.001298 | LR=2.52e-04
#    Epoch 090/100 | Train=0.001475 | Val=0.001462 | LR=2.02e-04
#    ⏹️  Early stopping at epoch 91 (best val=0.000014)
#    ✅ Loaded best model (val loss: 0.000014)
#
#    📊 Test Metrics:
#       MAE: 5.674500e-06
#       Pearson r: 0.511 (p=6.582e-01)
#       R²: -7.532
#       Horizon MAE: T0=3.25e-06, T1=7.37e-06, T2=6.40e-06
#    ⏱️  Fold time: 0.6 minutes
#
# ======================================================================
# FOLD 22/33 | Test: AR11476_M5.7
# ======================================================================
#    Train: 31 flares
#    Val: AR11515_M5.6
#    Test: AR11476_M5.7
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.011115 | Val=0.002751 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004945 | Val=0.001580 | LR=1.27e-04
#    Epoch 020/100 | Train=0.005079 | Val=0.002150 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003378 | Val=0.002330 | LR=2.47e-04
#    Epoch 040/100 | Train=0.003347 | Val=0.002430 | LR=1.38e-04
#    Epoch 050/100 | Train=0.002981 | Val=0.001388 | LR=3.59e-05
#    Epoch 060/100 | Train=0.004262 | Val=0.001771 | LR=3.00e-04
#    Epoch 070/100 | Train=0.004866 | Val=0.001610 | LR=2.86e-04
#    Epoch 080/100 | Train=0.004130 | Val=0.001666 | LR=2.52e-04
#    Epoch 090/100 | Train=0.002606 | Val=0.002416 | LR=2.02e-04
#    Epoch 099/100 | Train=0.001939 | Val=0.003907 | LR=1.50e-04
#    ✅ Loaded best model (val loss: 0.001120)
#
#    📊 Test Metrics:
#       MAE: 6.209375e-07
#       Pearson r: 0.999 (p=2.685e-02)
#       R²: -0.021
#       Horizon MAE: T0=6.65e-07, T1=7.55e-07, T2=4.42e-07
#    ⏱️  Fold time: 0.6 minutes
#
# ======================================================================
# FOLD 23/33 | Test: AR11515_M5.6
# ======================================================================
#    Train: 31 flares
#    Val: AR11515_M5.3
#    Test: AR11515_M5.6
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.010917 | Val=0.000985 | LR=2.98e-04
#    Epoch 010/100 | Train=0.005210 | Val=0.000070 | LR=1.27e-04
#    Epoch 020/100 | Train=0.003728 | Val=0.000112 | LR=3.00e-04
#    Epoch 030/100 | Train=0.006374 | Val=0.004727 | LR=2.47e-04
#    Epoch 040/100 | Train=0.003752 | Val=0.002960 | LR=1.38e-04
#    Epoch 050/100 | Train=0.003572 | Val=0.001970 | LR=3.59e-05
#    Epoch 060/100 | Train=0.002717 | Val=0.007747 | LR=3.00e-04
#    ⏹️  Early stopping at epoch 63 (best val=0.000052)
#    ✅ Loaded best model (val loss: 0.000052)
#
#    📊 Test Metrics:
#       MAE: 7.475309e-06
#       Pearson r: -0.998 (p=3.930e-02)
#       R²: -0.940
#       Horizon MAE: T0=1.28e-05, T1=6.01e-06, T2=3.60e-06
#    ⏱️  Fold time: 0.4 minutes
#
# ======================================================================
# FOLD 24/33 | Test: AR11515_M5.3
# ======================================================================
#    Train: 31 flares
#    Val: AR11515_M6.1
#    Test: AR11515_M5.3
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.013799 | Val=0.003840 | LR=2.98e-04
#    Epoch 010/100 | Train=0.006091 | Val=0.000558 | LR=1.27e-04
#    Epoch 020/100 | Train=0.003498 | Val=0.000437 | LR=3.00e-04
#    Epoch 030/100 | Train=0.006124 | Val=0.003234 | LR=2.47e-04
#    Epoch 040/100 | Train=0.004447 | Val=0.002618 | LR=1.38e-04
#    Epoch 050/100 | Train=0.002290 | Val=0.004957 | LR=3.59e-05
#    Epoch 060/100 | Train=0.002826 | Val=0.004813 | LR=3.00e-04
#    Epoch 070/100 | Train=0.004811 | Val=0.008755 | LR=2.86e-04
#    ⏹️  Early stopping at epoch 70 (best val=0.000437)
#    ✅ Loaded best model (val loss: 0.000437)
#
#    📊 Test Metrics:
#       MAE: 4.220958e-06
#       Pearson r: -0.834 (p=3.726e-01)
#       R²: -9.760
#       Horizon MAE: T0=1.25e-07, T1=6.37e-06, T2=6.16e-06
#    ⏱️  Fold time: 0.4 minutes
#
# ======================================================================
# FOLD 25/33 | Test: AR11515_M6.1
# ======================================================================
#    Train: 31 flares
#    Val: AR11877_M9.3
#    Test: AR11515_M6.1
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.012811 | Val=0.000449 | LR=2.98e-04
#    Epoch 010/100 | Train=0.003987 | Val=0.000445 | LR=1.27e-04
#    Epoch 020/100 | Train=0.005508 | Val=0.014576 | LR=3.00e-04
#    Epoch 030/100 | Train=0.006264 | Val=0.001136 | LR=2.47e-04
#    Epoch 040/100 | Train=0.001547 | Val=0.000277 | LR=1.38e-04
#    Epoch 050/100 | Train=0.003647 | Val=0.002482 | LR=3.59e-05
#    Epoch 060/100 | Train=0.002744 | Val=0.001820 | LR=3.00e-04
#    ⏹️  Early stopping at epoch 62 (best val=0.000121)
#    ✅ Loaded best model (val loss: 0.000121)
#
#    📊 Test Metrics:
#       MAE: 6.256923e-06
#       Pearson r: -0.724 (p=4.844e-01)
#       R²: -15.514
#       Horizon MAE: T0=1.29e-05, T1=4.81e-06, T2=1.02e-06
#    ⏱️  Fold time: 0.4 minutes
#
# ======================================================================
# FOLD 26/33 | Test: AR11877_M9.3
# ======================================================================
#    Train: 31 flares
#    Val: AR11884_M6.3
#    Test: AR11877_M9.3
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.011974 | Val=0.001677 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004995 | Val=0.001615 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004170 | Val=0.001210 | LR=3.00e-04
#    Epoch 030/100 | Train=0.006206 | Val=0.000382 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002993 | Val=0.000674 | LR=1.38e-04
#    Epoch 050/100 | Train=0.003372 | Val=0.000192 | LR=3.59e-05
#    Epoch 060/100 | Train=0.004235 | Val=0.000448 | LR=3.00e-04
#    ⏹️  Early stopping at epoch 62 (best val=0.000006)
#    ✅ Loaded best model (val loss: 0.000006)
#
#    📊 Test Metrics:
#       MAE: 5.945738e-06
#       Pearson r: -0.203 (p=8.701e-01)
#       R²: -5.703
#       Horizon MAE: T0=9.85e-06, T1=4.94e-06, T2=3.04e-06
#    ⏱️  Fold time: 0.4 minutes
#
# ======================================================================
# FOLD 27/33 | Test: AR11884_M6.3
# ======================================================================
#    Train: 31 flares
#    Val: AR11884_M5.0
#    Test: AR11884_M6.3
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.013974 | Val=0.003518 | LR=2.98e-04
#    Epoch 010/100 | Train=0.005005 | Val=0.000939 | LR=1.27e-04
#    Epoch 020/100 | Train=0.006948 | Val=0.000675 | LR=3.00e-04
#    Epoch 030/100 | Train=0.005764 | Val=0.002498 | LR=2.47e-04
#    Epoch 040/100 | Train=0.003789 | Val=0.000693 | LR=1.38e-04
#    Epoch 050/100 | Train=0.004178 | Val=0.000499 | LR=3.59e-05
#    Epoch 060/100 | Train=0.003161 | Val=0.000465 | LR=3.00e-04
#    ⏹️  Early stopping at epoch 61 (best val=0.000009)
#    ✅ Loaded best model (val loss: 0.000009)
#
#    📊 Test Metrics:
#       MAE: 1.768599e-06
#       Pearson r: 0.188 (p=8.798e-01)
#       R²: -7.276
#       Horizon MAE: T0=1.76e-06, T1=3.06e-06, T2=4.87e-07
#    ⏱️  Fold time: 0.4 minutes
#
# ======================================================================
# FOLD 28/33 | Test: AR11884_M5.0
# ======================================================================
#    Train: 31 flares
#    Val: AR11890_X1.1a
#    Test: AR11884_M5.0
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.012690 | Val=0.004340 | LR=2.98e-04
#    Epoch 010/100 | Train=0.008298 | Val=0.003316 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004512 | Val=0.002859 | LR=3.00e-04
#    Epoch 030/100 | Train=0.007901 | Val=0.000258 | LR=2.47e-04
#    Epoch 040/100 | Train=0.003195 | Val=0.006322 | LR=1.38e-04
#    Epoch 050/100 | Train=0.002352 | Val=0.000964 | LR=3.59e-05
#    Epoch 060/100 | Train=0.003414 | Val=0.000932 | LR=3.00e-04
#    Epoch 070/100 | Train=0.003077 | Val=0.001485 | LR=2.86e-04
#    ⏹️  Early stopping at epoch 79 (best val=0.000113)
#    ✅ Loaded best model (val loss: 0.000113)
#
#    📊 Test Metrics:
#       MAE: 2.541773e-06
#       Pearson r: 0.734 (p=4.758e-01)
#       R²: -35.438
#       Horizon MAE: T0=2.19e-06, T1=5.94e-07, T2=4.85e-06
#    ⏱️  Fold time: 0.5 minutes
#
# ======================================================================
# FOLD 29/33 | Test: AR11890_X1.1a
# ======================================================================
#    Train: 31 flares
#    Val: AR11890_X1.1b
#    Test: AR11890_X1.1a
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.012222 | Val=0.003572 | LR=2.98e-04
#    Epoch 010/100 | Train=0.005110 | Val=0.002123 | LR=1.27e-04
#    Epoch 020/100 | Train=0.005257 | Val=0.009722 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003435 | Val=0.006468 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002632 | Val=0.001077 | LR=1.38e-04
#    Epoch 050/100 | Train=0.002919 | Val=0.004392 | LR=3.59e-05
#    Epoch 060/100 | Train=0.003266 | Val=0.001325 | LR=3.00e-04
#    Epoch 070/100 | Train=0.003163 | Val=0.000220 | LR=2.86e-04
#    Epoch 080/100 | Train=0.002720 | Val=0.004531 | LR=2.52e-04
#    Epoch 090/100 | Train=0.004515 | Val=0.001415 | LR=2.02e-04
#    Epoch 099/100 | Train=0.003225 | Val=0.005168 | LR=1.50e-04
#    ✅ Loaded best model (val loss: 0.000220)
#
#    📊 Test Metrics:
#       MAE: 3.184192e-06
#       Pearson r: 0.006 (p=9.959e-01)
#       R²: -0.175
#       Horizon MAE: T0=5.39e-06, T1=1.38e-06, T2=2.78e-06
#    ⏱️  Fold time: 0.6 minutes
#
# ======================================================================
# FOLD 30/33 | Test: AR11890_X1.1b
# ======================================================================
#    Train: 31 flares
#    Val: AR11936_M6.4
#    Test: AR11890_X1.1b
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.014815 | Val=0.003587 | LR=2.98e-04
#    Epoch 010/100 | Train=0.005438 | Val=0.001133 | LR=1.27e-04
#    Epoch 020/100 | Train=0.006018 | Val=0.001621 | LR=3.00e-04
#    Epoch 030/100 | Train=0.005555 | Val=0.009208 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002490 | Val=0.000694 | LR=1.38e-04
#    Epoch 050/100 | Train=0.002897 | Val=0.000925 | LR=3.59e-05
#    Epoch 060/100 | Train=0.002170 | Val=0.000886 | LR=3.00e-04
#    Epoch 070/100 | Train=0.005154 | Val=0.001167 | LR=2.86e-04
#    ⏹️  Early stopping at epoch 71 (best val=0.000557)
#    ✅ Loaded best model (val loss: 0.000557)
#
#    📊 Test Metrics:
#       MAE: 5.843511e-06
#       Pearson r: 0.295 (p=8.093e-01)
#       R²: -10.557
#       Horizon MAE: T0=5.02e-06, T1=4.18e-06, T2=8.33e-06
#    ⏱️  Fold time: 0.4 minutes
#
# ======================================================================
# FOLD 31/33 | Test: AR11936_M6.4
# ======================================================================
#    Train: 31 flares
#    Val: AR11944_M7.2
#    Test: AR11936_M6.4
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.009996 | Val=0.001513 | LR=2.98e-04
#    Epoch 010/100 | Train=0.003107 | Val=0.012344 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004132 | Val=0.000220 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003893 | Val=0.008133 | LR=2.47e-04
#    Epoch 040/100 | Train=0.003713 | Val=0.000253 | LR=1.38e-04
#    Epoch 050/100 | Train=0.003644 | Val=0.000976 | LR=3.59e-05
#    Epoch 060/100 | Train=0.004754 | Val=0.011434 | LR=3.00e-04
#    Epoch 070/100 | Train=0.004923 | Val=0.014979 | LR=2.86e-04
#    Epoch 080/100 | Train=0.002622 | Val=0.016436 | LR=2.52e-04
#    ⏹️  Early stopping at epoch 83 (best val=0.000014)
#    ✅ Loaded best model (val loss: 0.000014)
#
#    📊 Test Metrics:
#       MAE: 5.993056e-06
#       Pearson r: -0.908 (p=2.746e-01)
#       R²: -3.062
#       Horizon MAE: T0=1.02e-05, T1=2.81e-06, T2=4.93e-06
#    ⏱️  Fold time: 0.6 minutes
#
# ======================================================================
# FOLD 32/33 | Test: AR11944_M7.2
# ======================================================================
#    Train: 31 flares
#    Val: AR12035_X1.3
#    Test: AR11944_M7.2
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.008859 | Val=0.009740 | LR=2.98e-04
#    Epoch 010/100 | Train=0.007016 | Val=0.002769 | LR=1.27e-04
#    Epoch 020/100 | Train=0.005659 | Val=0.001407 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003908 | Val=0.020135 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002331 | Val=0.071444 | LR=1.38e-04
#    Epoch 050/100 | Train=0.003616 | Val=0.096761 | LR=3.59e-05
#    Epoch 060/100 | Train=0.002809 | Val=0.051618 | LR=3.00e-04
#    Epoch 070/100 | Train=0.002635 | Val=0.068105 | LR=2.86e-04
#    ⏹️  Early stopping at epoch 72 (best val=0.000176)
#    ✅ Loaded best model (val loss: 0.000176)
#
#    📊 Test Metrics:
#       MAE: 7.002173e-06
#       Pearson r: 0.798 (p=4.120e-01)
#       R²: -6.458
#       Horizon MAE: T0=7.25e-06, T1=3.99e-06, T2=9.77e-06
#    ⏱️  Fold time: 0.6 minutes
#
# ======================================================================
# FOLD 33/33 | Test: AR12035_X1.3
# ======================================================================
#    Train: 31 flares
#    Val: AR11158_M6.6
#    Test: AR12035_X1.3
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.011696 | Val=0.015543 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004605 | Val=0.000290 | LR=1.27e-04
#    Epoch 020/100 | Train=0.003663 | Val=0.000309 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003544 | Val=0.125644 | LR=2.47e-04
#    Epoch 040/100 | Train=0.003640 | Val=0.002697 | LR=1.38e-04
#    Epoch 050/100 | Train=0.002713 | Val=0.007084 | LR=3.59e-05
#    Epoch 060/100 | Train=0.002947 | Val=0.025681 | LR=3.00e-04
#    Epoch 070/100 | Train=0.002072 | Val=0.000854 | LR=2.86e-04
#    Epoch 080/100 | Train=0.003119 | Val=0.005864 | LR=2.52e-04
#    Epoch 090/100 | Train=0.002465 | Val=0.003643 | LR=2.02e-04
#    Epoch 099/100 | Train=0.004249 | Val=0.011190 | LR=1.50e-04
#    ✅ Loaded best model (val loss: 0.000018)
#
#    📊 Test Metrics:
#       MAE: 2.193417e-05
#       Pearson r: -0.909 (p=2.736e-01)
#       R²: -47.555
#       Horizon MAE: T0=1.70e-05, T1=2.04e-05, T2=2.84e-05
#    ⏱️  Fold time: 0.6 minutes
#
# ======================================================================
# LOFO COMPLETE - BASELINE CNN
# ======================================================================
# Total time: 17.0 minutes (0.3 hours)
# Avg per fold: 0.5 minutes
#
# SUMMARY STATISTICS:
#   MAE: 6.251220e-06 ± 4.457819e-06
#   R² (valid): -20.071 ± 23.516
# ✅ Results saved to results_lofo_baseline_cnn/

# %%
# %%
# ============================================================
# CELL 9: GLOBAL METRICS ACROSS ALL FOLDS
# ============================================================
print("\n" + "="*70)
print("COMPUTING GLOBAL METRICS ACROSS ALL FOLDS")
print("="*70)

# Aggregate all predictions and targets
all_preds = np.concatenate([m['preds'] for _, m in results], axis=0)
all_trues = np.concatenate([m['trues'] for _, m in results], axis=0)

print(f"\nAggregated data:")
print(f"  Total samples: {len(all_preds)} flares × 3 horizons = {len(all_preds) * 3} predictions")
print(f"  Shape: preds={all_preds.shape}, trues={all_trues.shape}")

# Flatten for global correlation
preds_flat = all_preds.ravel()
trues_flat = all_trues.ravel()

# Global metrics
global_mae = mean_absolute_error(trues_flat, preds_flat)
global_r, global_p = pearsonr(trues_flat, preds_flat)
global_r2 = r2_score(trues_flat, preds_flat)

# Relative error
rel_errors = np.abs((preds_flat - trues_flat) / (trues_flat + 1e-8))
global_rel_error = np.mean(rel_errors) * 100

print(f"\n{'='*70}")
print("GLOBAL METRICS (Across All Folds)")
print(f"{'='*70}")
print(f"  MAE: {global_mae:.6e} W/m²/nm")
print(f"  Pearson r: {global_r:.3f} (p={global_p:.3e})")
print(f"  R²: {global_r2:.3f}")
print(f"  Relative Error: {global_rel_error:.1f}%")

# Per-horizon global metrics
print(f"\nPer-Horizon Metrics:")
horizon_metrics = {}
for i, horizon in enumerate(['T0', 'T1', 'T2']):
    mae_h = mean_absolute_error(all_trues[:, i], all_preds[:, i])
    r_h, p_h = pearsonr(all_trues[:, i], all_preds[:, i])
    print(f"  {horizon:4s}: MAE={mae_h:.6e}, r={r_h:.3f}, p={p_h:.3e}")
    
    # Store as native Python floats for JSON
    horizon_metrics[horizon] = {
        'mae': float(mae_h),
        'r': float(r_h),
        'p': float(p_h)
    }

# Save global metrics (convert all numpy types to Python native types)
global_metrics = {
    'global_mae': float(global_mae),
    'global_r': float(global_r),
    'global_r2': float(global_r2),
    'global_p_value': float(global_p),
    'global_rel_error_pct': float(global_rel_error),
    'num_folds': int(len(results)),
    'num_samples': int(len(all_preds)),
    'horizon_metrics': horizon_metrics
}

import json
with open("results_lofo_baseline_cnn/global_metrics.json", "w") as f:  # ← CHANGED
    json.dump(global_metrics, f, indent=2)

print(f"\n✅ Global metrics saved to results_lofo_baseline_cnn/global_metrics.json")  # ← CHANGED

# Interpretation
print(f"\n{'='*70}")
print("INTERPRETATION")
print(f"{'='*70}")

if global_r > 0.85:
    print("✅ EXCELLENT: r > 0.85 indicates strong predictive skill")
elif global_r > 0.70:
    print("✅ GOOD: r > 0.70 indicates reasonable predictive skill")
elif global_r > 0.50:
    print("⚠️  MODERATE: r > 0.50 suggests some predictive skill")
else:
    print("❌ POOR: r < 0.50 indicates weak predictive skill")

if global_r2 > 0.70:
    print(f"✅ Model explains {global_r2*100:.1f}% of variance")
elif global_r2 > 0.50:
    print(f"⚠️  Model explains {global_r2*100:.1f}% of variance (moderate)")
else:
    print(f"❌ Model explains only {global_r2*100:.1f}% of variance (poor)")

print("\n✅ Cell 9 complete!")
# Out:
# ======================================================================
# COMPUTING GLOBAL METRICS ACROSS ALL FOLDS
# ======================================================================
#
# Aggregated data:
#   Total samples: 33 flares × 3 horizons = 99 predictions
#   Shape: preds=(33, 3), trues=(33, 3)
#
# ======================================================================
# GLOBAL METRICS (Across All Folds)
# ======================================================================
#   MAE: 6.251220e-06 W/m²/nm
#   Pearson r: 0.885 (p=5.548e-34)
#   R²: 0.716
#   Relative Error: 7.1%
#
# Per-Horizon Metrics:
#   T0  : MAE=6.355628e-06, r=0.895, p=2.262e-12
#   T1  : MAE=5.918210e-06, r=0.897, p=1.496e-12
#   T2  : MAE=6.479824e-06, r=0.863, p=1.056e-10
#
# ✅ Global metrics saved to results_lofo_baseline_cnn/global_metrics.json
#
# ======================================================================
# INTERPRETATION
# ======================================================================
# ✅ EXCELLENT: r > 0.85 indicates strong predictive skill
# ✅ Model explains 71.6% of variance
#
# ✅ Cell 9 complete!
