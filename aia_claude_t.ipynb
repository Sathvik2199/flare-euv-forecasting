# %%
# %%
# ============================================================
# CELL 1: Imports and Configuration (AIA-ONLY)
# ============================================================
import os, warnings, numpy as np, pandas as pd
import torch, torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from torchvision import models
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import sys
import time

print("Torch:", torch.__version__, " | Numpy:", np.__version__, " | Python:", sys.version)

warnings.filterwarnings("ignore")
torch.manual_seed(42)
np.random.seed(42)

device = "mps" if hasattr(torch.backends, "mps") and torch.backends.mps.is_available() else \
         ("cuda" if torch.cuda.is_available() else "cpu")
print("✅ Device:", device)

# ============================================================
# OPTIMIZED CONFIGURATION FOR 33 FLARES (AIA-ONLY: 8 CHANNELS)
# ============================================================
DATA_DIR = "preprocessed_data"
IMG_CHANNELS = 8   # ← CHANGED from 13 to 8 (AIA only)
IMG_SIZE = 256
EPOCHS = 100
BATCH_SIZE = 2
LR = 3e-4
WEIGHT_DECAY = 1e-4
SCHED_STEP, SCHED_GAMMA = 25, 0.5
TARGET_SCALE = 1e-4
LOSS_WEIGHTS = torch.tensor([0.5, 0.3, 0.2], dtype=torch.float32)

print(f"""
OPTIMIZED CONFIGURATION FOR 33 FLARES (AIA-ONLY):
- Channels: {IMG_CHANNELS} (AIA EUV/UV only)
- Image Size: {IMG_SIZE}×{IMG_SIZE}
- Epochs: {EPOCHS}
- Batch Size: {BATCH_SIZE}
- Learning Rate: {LR}
- Scheduler: StepLR (step={SCHED_STEP}, gamma={SCHED_GAMMA})
""")
# Out:
# Torch: 2.8.0  | Numpy: 2.2.6  | Python: 3.11.13 (main, Jun  5 2025, 08:21:08) [Clang 14.0.6 ]
# ✅ Device: mps
#
# OPTIMIZED CONFIGURATION FOR 33 FLARES (AIA-ONLY):
# - Channels: 8 (AIA EUV/UV only)
# - Image Size: 256×256
# - Epochs: 100
# - Batch Size: 2
# - Learning Rate: 0.0003
# - Scheduler: StepLR (step=25, gamma=0.5)

# %%
# %%
# ============================================================
# CELL 2: Load Dataset (AIA-ONLY)
# ============================================================
# Extract only AIA channels (first 8) from the preprocessed data

try:
    X_full = np.load(os.path.join(DATA_DIR, "X_aiahmi_256.npy"))  # Load full 13-channel data
    Y = np.load(os.path.join(DATA_DIR, "Y_aiahmi_256.npy"))
    
    # ← CHANGED: Extract only AIA channels (first 8)
    X = X_full[:, :8, :, :]
    
    print(f"✅ Loaded 256×256 dataset (AIA-only)")
    print(f"   Full data: {X_full.shape}")
    print(f"   AIA-only: {X.shape} (extracted channels 0-7)")
    print(f"   Y: {Y.shape}")
    
except FileNotFoundError:
    print("⚠️  256×256 data not found, loading 128×128...")
    X_full = np.load(os.path.join(DATA_DIR, "X_aiahmi.npy"))
    Y = np.load(os.path.join(DATA_DIR, "Y_aiahmi.npy"))
    
    # ← CHANGED: Extract only AIA channels (first 8)
    X = X_full[:, :8, :, :]
    
    print(f"⚠️  Using 128×128 dataset (AIA-only)")
    print(f"   Full data: {X_full.shape}")
    print(f"   AIA-only: {X.shape}")
    print(f"   Consider regenerating at 256×256 for better performance!")

# Verify channel count
assert X.shape[1] == 8, f"Expected 8 AIA channels, got {X.shape[1]}"

# Zero-mean target scaling
Y_scaled = (Y - Y.mean(axis=0)) / TARGET_SCALE
print(f"\nTarget scaling: Mean={Y.mean(axis=0)}, Scale={TARGET_SCALE}")

# Load flare IDs
flare_ids = pd.read_csv("flare_euv_targets_3day.csv")["flare_id"].tolist()
assert len(flare_ids) == len(X), f"Mismatch: {len(X)} samples vs {len(flare_ids)} flare IDs"
print(f"✅ Loaded {len(flare_ids)} flares")

# Print dataset statistics
print(f"\nDataset Statistics:")
print(f"  X shape: {X.shape} (N, 8_AIA_channels, 256, 256)")
print(f"  Min/Max irradiance: {Y.min():.2e} / {Y.max():.2e}")
print(f"  Mean ± Std: {Y.mean():.2e} ± {Y.std():.2e}")
# Out:
# ✅ Loaded 256×256 dataset (AIA-only)
#    Full data: (33, 13, 256, 256)
#    AIA-only: (33, 8, 256, 256) (extracted channels 0-7)
#    Y: (33, 3)
#
# Target scaling: Mean=[8.8646077e-05 8.8066365e-05 8.8103399e-05], Scale=0.0001
# ✅ Loaded 33 flares
#
# Dataset Statistics:
#   X shape: (33, 8, 256, 256) (N, 8_AIA_channels, 256, 256)
#   Min/Max irradiance: 6.04e-05 / 1.21e-04
#   Mean ± Std: 8.83e-05 ± 1.53e-05

# %%
# %%
# ============================================================
# CELL 3: Global Standardization + Dataset Class
# ============================================================
def compute_global_stats(X):
    """Compute per-channel mean and std across all samples"""
    C = X.shape[1]
    means = np.array([X[:, c].mean() for c in range(C)], dtype=np.float32)
    stds  = np.array([X[:, c].std() + 1e-6 for c in range(C)], dtype=np.float32)
    return means, stds

GLOBAL_MEAN, GLOBAL_STD = compute_global_stats(X)
print("✅ Global statistics computed")
print(f"   Channel means: {GLOBAL_MEAN[:3]}... (showing first 3)")
print(f"   Channel stds:  {GLOBAL_STD[:3]}... (showing first 3)")

class FlareDataset(Dataset):
    def __init__(self, X, Y, mean, std, augment=False):
        self.X = X.astype(np.float32)
        self.Y = Y.astype(np.float32)
        self.mean = mean.astype(np.float32)
        self.std = std.astype(np.float32)
        self.augment = augment
    
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        x = (self.X[idx] - self.mean[:, None, None]) / self.std[:, None, None]
        y = self.Y[idx]
        
        # Data augmentation for training (random flips)
        if self.augment and np.random.rand() > 0.5:
            x = np.flip(x, axis=1).copy()  # Horizontal flip
        if self.augment and np.random.rand() > 0.5:
            x = np.flip(x, axis=2).copy()  # Vertical flip
        
        return torch.tensor(x), torch.tensor(y)

print("✅ Dataset class ready (with augmentation support)")
# Out:
# ✅ Global statistics computed
#    Channel means: [0.41056433 0.49668843 0.7356721 ]... (showing first 3)
#    Channel stds:  [0.18767157 0.23753043 0.21912515]... (showing first 3)
# ✅ Dataset class ready (with augmentation support)

# %%
# %%
# ============================================================
# CELL 4: IMPROVED MODEL - ResNet34 with Channel Attention (AIA-ONLY)
# ============================================================
class ChannelAttention(nn.Module):
    """Squeeze-and-Excitation block for channel attention"""
    def __init__(self, channels, reduction=16):
        super().__init__()
        self.fc = nn.Sequential(
            nn.Linear(channels, channels // reduction, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(channels // reduction, channels, bias=False),
            nn.Sigmoid()
        )
    
    def forward(self, x):
        b, c, _, _ = x.size()
        # Global average pooling
        y = x.view(b, c, -1).mean(dim=2)
        # Channel attention
        y = self.fc(y).view(b, c, 1, 1)
        return x * y.expand_as(x)


class ImprovedEUVRegressor(nn.Module):
    """
    Enhanced ResNet34 with:
    - 8-channel input stem (AIA-only)
    - Channel attention
    - Dropout regularization
    - Optimized for 33-flare dataset
    """
    def __init__(self, in_channels=8, out_features=3, dropout=0.3):  # ← CHANGED default to 8
        super().__init__()
        
        # Load pretrained ResNet34 (more capacity than ResNet18)
        resnet = models.resnet34(weights=models.ResNet34_Weights.IMAGENET1K_V1)
        
        # Modify first conv for 8 channels (AIA-only)  # ← CHANGED comment
        first_conv = resnet.conv1
        resnet.conv1 = nn.Conv2d(
            in_channels, 
            first_conv.out_channels,
            kernel_size=first_conv.kernel_size,
            stride=first_conv.stride,
            padding=first_conv.padding,
            bias=False
        )
        
        # Initialize new channels intelligently
        with torch.no_grad():
            # Copy pretrained RGB weights to first 3 channels
            resnet.conv1.weight[:, :3] = first_conv.weight
            
            # Initialize remaining channels with mean of RGB
            mean_weights = first_conv.weight.mean(dim=1, keepdim=True)
            for i in range(3, in_channels):
                resnet.conv1.weight[:, i:i+1] = mean_weights
        
        # Add channel attention after each residual block
        self.attention1 = ChannelAttention(64)
        self.attention2 = ChannelAttention(128)
        self.attention3 = ChannelAttention(256)
        self.attention4 = ChannelAttention(512)
        
        # Store ResNet layers
        self.conv1 = resnet.conv1
        self.bn1 = resnet.bn1
        self.relu = resnet.relu
        self.maxpool = resnet.maxpool
        
        self.layer1 = resnet.layer1
        self.layer2 = resnet.layer2
        self.layer3 = resnet.layer3
        self.layer4 = resnet.layer4
        
        self.avgpool = resnet.avgpool
        
        # Enhanced regression head
        self.fc = nn.Sequential(
            nn.Dropout(dropout),
            nn.Linear(512, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout / 2),
            nn.Linear(256, out_features)
        )
    
    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.maxpool(x)
        
        x = self.layer1(x)
        x = self.attention1(x)
        
        x = self.layer2(x)
        x = self.attention2(x)
        
        x = self.layer3(x)
        x = self.attention3(x)
        
        x = self.layer4(x)
        x = self.attention4(x)
        
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.fc(x)
        
        return x

# Test model (with 8 channels for AIA-only)  # ← CHANGED comment
test_model = ImprovedEUVRegressor(in_channels=8)  # ← CHANGED: explicit in_channels=8
total_params = sum(p.numel() for p in test_model.parameters())
trainable_params = sum(p.numel() for p in test_model.parameters() if p.requires_grad)

print("✅ ImprovedEUVRegressor (ResNet34 + Channel Attention) - AIA-ONLY")  # ← CHANGED
print(f"   Input channels: 8 (AIA EUV/UV)")  # ← ADDED
print(f"   Total parameters: {total_params:,}")
print(f"   Trainable parameters: {trainable_params:,}")
del test_model
# Out:
# ✅ ImprovedEUVRegressor (ResNet34 + Channel Attention) - AIA-ONLY
#    Input channels: 8 (AIA EUV/UV)
#    Total parameters: 21,475,971
#    Trainable parameters: 21,475,971

# %%
# %%
# ============================================================
# CELL 5: Loss Function
# ============================================================
def loss_fn_weighted(pred, target, weights=LOSS_WEIGHTS):
    """Horizon-weighted MSE loss"""
    diff2 = (pred - target) ** 2
    weighted = diff2 * weights.to(pred.device)
    return weighted.mean()

print("✅ Weighted MSE loss function ready")
print(f"   Horizon weights: {LOSS_WEIGHTS.numpy()}")
# Out:
# ✅ Weighted MSE loss function ready
#    Horizon weights: [0.5 0.3 0.2]

# %%
# %%
# ============================================================
# CELL 6: Training Functions (OPTIMIZED)
# ============================================================
def train_one_epoch(model, loader, optimizer):
    """Train for one epoch with gradient clipping"""
    model.train()
    epoch_losses = []
    
    for xb, yb in loader:
        xb = xb.to(device, dtype=torch.float32)
        yb = yb.to(device, dtype=torch.float32)
        
        optimizer.zero_grad()
        pred = model(xb)
        loss = loss_fn_weighted(pred, yb)
        loss.backward()
        
        # Gradient clipping for stability
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        optimizer.step()
        epoch_losses.append(loss.item())
    
    return np.mean(epoch_losses)


def validate_epoch(model, loader):
    """Validate without gradient computation"""
    model.eval()
    val_losses = []
    
    with torch.no_grad():
        for xb, yb in loader:
            xb = xb.to(device, dtype=torch.float32)
            yb = yb.to(device, dtype=torch.float32)
            
            pred = model(xb)
            loss = loss_fn_weighted(pred, yb)
            val_losses.append(loss.item())
    
    return np.mean(val_losses)


def train_with_validation(model, train_loader, val_loader, epochs=EPOCHS, patience=50):
    """
    Train with validation-based early stopping
    OPTIMIZED FOR 33 FLARES
    """
    model = model.to(device, dtype=torch.float32)
    
    # Optimizer with weight decay
    optimizer = torch.optim.AdamW(
        model.parameters(), 
        lr=LR, 
        weight_decay=WEIGHT_DECAY,
        betas=(0.9, 0.999)
    )
    
    # Cosine annealing with warm restarts (better than StepLR)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
        optimizer, 
        T_0=20,  # Restart every 20 epochs
        T_mult=2  # Double restart interval each time
    )
    
    best_val_loss = float("inf")
    best_state = None
    patience_counter = 0
    
    print(f"   Training for up to {epochs} epochs (patience={patience})...")
    
    for ep in range(epochs):
        # Train
        train_loss = train_one_epoch(model, train_loader, optimizer)
        
        # Validate
        val_loss = validate_epoch(model, val_loader)
        
        # Step scheduler
        scheduler.step()
        
        # Get current learning rate
        current_lr = optimizer.param_groups[0]['lr']
        
        # Print progress
        if ep % 10 == 0 or ep == epochs - 1:
            print(f"   Epoch {ep:03d}/{epochs} | Train={train_loss:.6f} | Val={val_loss:.6f} | LR={current_lr:.2e}")
        
        # Early stopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"   ⏹️  Early stopping at epoch {ep} (best val={best_val_loss:.6f})")
                break
    
    # Load best model
    if best_state is not None:
        model.load_state_dict(best_state)
        print(f"   ✅ Loaded best model (val loss: {best_val_loss:.6f})")
    
    return model

print("✅ Training functions ready")
# Out:
# ✅ Training functions ready

# %%
# %%
# ============================================================
# CELL 7: Evaluation Function (FIXED)
# ============================================================
def evaluate(model, loader):
    """
    Comprehensive evaluation with multiple metrics
    FIXED: Handles single-sample test sets (LOFO)
    """
    model.eval()
    preds, trues = [], []
    
    with torch.no_grad():
        for xb, yb in loader:
            xb = xb.to(device, dtype=torch.float32)
            yb = yb.to(device, dtype=torch.float32)
            p = model(xb)
            preds.extend(p.cpu().numpy())
            trues.extend(yb.cpu().numpy())
    
    # Denormalize
    preds = np.array(preds) * TARGET_SCALE + Y.mean(axis=0)
    trues = np.array(trues) * TARGET_SCALE + Y.mean(axis=0)
    
    # Flatten for global metrics
    preds_flat = preds.ravel()
    trues_flat = trues.ravel()
    
    # Global metrics (across all horizons)
    mae = mean_absolute_error(trues_flat, preds_flat)
    
    # Pearson correlation - handle single sample case
    if len(trues_flat) >= 2:
        r, p_value = pearsonr(trues_flat, preds_flat)
        r2 = r2_score(trues_flat, preds_flat)
    else:
        # For single sample, use absolute error as proxy
        r = np.nan
        p_value = np.nan
        r2 = np.nan
    
    # Per-horizon metrics
    mae_per_horizon = []
    r_per_horizon = []
    
    for i in range(3):
        # MAE per horizon (always computable)
        mae_h = mean_absolute_error(trues[:, i], preds[:, i])
        mae_per_horizon.append(mae_h)
        
        # Correlation per horizon (requires 2+ samples)
        if len(trues[:, i]) >= 2:
            r_h, _ = pearsonr(trues[:, i], preds[:, i])
            r_per_horizon.append(r_h)
        else:
            r_per_horizon.append(np.nan)
    
    return {
        'mae': mae,
        'r': r,
        'r2': r2,
        'p_value': p_value,
        'preds': preds,
        'trues': trues,
        'mae_per_horizon': mae_per_horizon,
        'r_per_horizon': r_per_horizon
    }

print("✅ Evaluation function ready (handles single-sample LOFO)")
# Out:
# ✅ Evaluation function ready (handles single-sample LOFO)

# %%
# %%
# ============================================================
# CELL 8: CORRECTED LOFO CROSS-VALIDATION (AIA-ONLY, NO LEAKAGE)
# ============================================================
import csv

os.makedirs("results_aia_only", exist_ok=True)
results = []

print("\n" + "="*70)
print("LOFO CROSS-VALIDATION - AIA-ONLY BASELINE (NO LEAKAGE)")
print("="*70)
print(f"Total flares: {len(flare_ids)}")
print(f"Channels: {IMG_CHANNELS} (AIA EUV/UV only)")
print(f"Train/Val/Test split: {len(flare_ids)-2} / 1 / 1 per fold")
print("="*70)

total_start_time = time.time()

for test_idx, test_flare in enumerate(flare_ids):
    fold_start_time = time.time()

    print(f"\n{'='*70}")
    print(f"FOLD {test_idx + 1}/{len(flare_ids)} | Test: {test_flare}")
    print(f"{'='*70}")

    # ---- 1) Create masks ----
    test_mask = np.zeros(len(X), dtype=bool)
    test_mask[test_idx] = True

    train_indices = np.where(~test_mask)[0]
    val_idx = train_indices[test_idx % len(train_indices)]  # rotate
    val_mask = np.zeros(len(X), dtype=bool)
    val_mask[val_idx] = True

    train_mask = ~test_mask & ~val_mask

    print(f"   Train: {np.sum(train_mask)} flares")
    print(f"   Val:   {flare_ids[val_idx]}")
    print(f"   Test:  {test_flare}")

    # ---- 2) TRAIN-ONLY NORMALIZATION  (NO LEAKAGE) ----
    X_train = X[train_mask]  # (Ntrain, C, H, W)
    train_mean = X_train.mean(axis=(0, 2, 3))
    train_std  = X_train.std(axis=(0, 2, 3)) + 1e-6

    print(f"   🔍 Train-only normalization applied")
    print(f"      Mean: {train_mean[:3]}..., Std: {train_std[:3]}...")

    # ---- 3) CREATE DATASETS (using ONLY train stats) ----
    ds_train = FlareDataset(X[train_mask], Y_scaled[train_mask],
                            train_mean, train_std, augment=True)
    ds_val   = FlareDataset(X[val_mask],   Y_scaled[val_mask],
                            train_mean, train_std, augment=False)
    ds_test  = FlareDataset(X[test_mask],  Y_scaled[test_mask],
                            train_mean, train_std, augment=False)

    train_loader = DataLoader(ds_train, batch_size=BATCH_SIZE, shuffle=True)
    val_loader   = DataLoader(ds_val,   batch_size=1, shuffle=False)
    test_loader  = DataLoader(ds_test,  batch_size=1, shuffle=False)

    # ---- 4) Initialize model ----
    model = ImprovedEUVRegressor(in_channels=8, out_features=3, dropout=0.3)
    model = train_with_validation(model, train_loader, val_loader,
                                  epochs=EPOCHS, patience=50)

    # ---- 5) Save & Evaluate ----
    model_path = f"results_aia_only/{test_flare}_model.pth"
    torch.save(model.state_dict(), model_path)

    metrics = evaluate(model, test_loader)
    results.append((test_flare, metrics))

    np.savez(f"results_aia_only/{test_flare}_preds.npz",
             flare=test_flare, preds=metrics['preds'], trues=metrics['trues'])

    fold_time = time.time() - fold_start_time

    print(f"\n   📊 Test Metrics:")
    print(f"      MAE:       {metrics['mae']:.6e}")
    print(f"      Pearson r: {metrics['r']:.3f} (p={metrics['p_value']:.3e})")
    print(f"      R²:        {metrics['r2']:.3f}")
    print(f"      Horizon MAE: T0={metrics['mae_per_horizon'][0]:.2e}, "
          f"T1={metrics['mae_per_horizon'][1]:.2e}, T2={metrics['mae_per_horizon'][2]:.2e}")
    print(f"   ⏱️  Fold time: {fold_time/60:.1f} minutes")

# ---- 6) Summary ----
total_time = time.time() - total_start_time

print("\n" + "="*70)
print("LOFO COMPLETE - AIA-ONLY BASELINE (SAFELY NORMALIZED)")
print("="*70)
print(f"Total time: {total_time/60:.1f} minutes ({total_time/3600:.1f} hours)")
print(f"Avg per fold: {total_time/len(flare_ids)/60:.1f} minutes\n")

all_maes = [m['mae'] for _, m in results]
all_r2s  = [m['r2'] for _, m in results if not np.isnan(m['r2'])]

print("SUMMARY STATISTICS:")
print(f"  MAE: {np.mean(all_maes):.6e} ± {np.std(all_maes):.6e}")
if len(all_r2s):
    print(f"  R² : {np.mean(all_r2s):.3f} ± {np.std(all_r2s):.3f}")
else:
    print(f"  R² : Not computable (single sample per test)")

# ---- 7) Export Summary ----
with open("results_aia_only/summary.csv", "w", newline="") as f:
    w = csv.writer(f)
    w.writerow(["flare_id", "MAE", "MAE_T0", "MAE_T1", "MAE_T2"])
    for fid, m in results:
        w.writerow([
            fid,
            f"{m['mae']:.6e}",
            f"{m['mae_per_horizon'][0]:.6e}",
            f"{m['mae_per_horizon'][1]:.6e}",
            f"{m['mae_per_horizon'][2]:.6e}"
        ])

print("✅ SAFE RESULTS SAVED to results_aia_only/")
# Out:
# ======================================================================
# LOFO CROSS-VALIDATION - AIA-ONLY BASELINE (NO LEAKAGE)
# ======================================================================
# Total flares: 33
# Channels: 8 (AIA EUV/UV only)
# Train/Val/Test split: 31 / 1 / 1 per fold
# ======================================================================
#
# ======================================================================
# FOLD 1/33 | Test: AR11158_M6.6
# ======================================================================
#    Train: 31 flares
#    Val:   AR11158_X2.2
#    Test:  AR11158_M6.6
#    🔍 Train-only normalization applied
#       Mean: [0.40907887 0.49675682 0.7351688 ]..., Std: [0.18720563 0.23737319 0.21867684]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.014485 | Val=0.021061 | LR=2.98e-04
#    Epoch 010/100 | Train=0.002609 | Val=0.001708 | LR=1.27e-04
#    Epoch 020/100 | Train=0.003267 | Val=0.001274 | LR=3.00e-04
#    Epoch 030/100 | Train=0.002103 | Val=0.005543 | LR=2.47e-04
#    Epoch 040/100 | Train=0.001868 | Val=0.004324 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001005 | Val=0.007962 | LR=3.59e-05
#    Epoch 060/100 | Train=0.001620 | Val=0.005133 | LR=3.00e-04
#    Epoch 070/100 | Train=0.001864 | Val=0.001590 | LR=2.86e-04
#    ⏹️  Early stopping at epoch 79 (best val=0.000078)
#    ✅ Loaded best model (val loss: 0.000078)
#
#    📊 Test Metrics:
#       MAE:       3.613175e-06
#       Pearson r: 0.540 (p=6.367e-01)
#       R²:        -8.303
#       Horizon MAE: T0=5.08e-06, T1=2.49e-06, T2=3.26e-06
#    ⏱️  Fold time: 1.8 minutes
#
# ======================================================================
# FOLD 2/33 | Test: AR11158_X2.2
# ======================================================================
#    Train: 31 flares
#    Val:   AR11261_M9.3
#    Test:  AR11158_X2.2
#    🔍 Train-only normalization applied
#       Mean: [0.40970844 0.49717563 0.7355425 ]..., Std: [0.18739672 0.23707457 0.21859698]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.013456 | Val=0.011947 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004390 | Val=0.001515 | LR=1.27e-04
#    Epoch 020/100 | Train=0.003152 | Val=0.005455 | LR=3.00e-04
#    Epoch 030/100 | Train=0.002682 | Val=0.000402 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002356 | Val=0.003698 | LR=1.38e-04
#    Epoch 050/100 | Train=0.000951 | Val=0.000434 | LR=3.59e-05
#    Epoch 060/100 | Train=0.001305 | Val=0.001883 | LR=3.00e-04
#    ⏹️  Early stopping at epoch 62 (best val=0.000015)
#    ✅ Loaded best model (val loss: 0.000015)
#
#    📊 Test Metrics:
#       MAE:       2.662308e-06
#       Pearson r: 0.167 (p=8.933e-01)
#       R²:        -8.943
#       Horizon MAE: T0=6.37e-06, T1=5.10e-07, T2=1.10e-06
#    ⏱️  Fold time: 1.4 minutes
#
# ======================================================================
# FOLD 3/33 | Test: AR11261_M9.3
# ======================================================================
#    Train: 31 flares
#    Val:   AR11429_X5.4
#    Test:  AR11261_M9.3
#    🔍 Train-only normalization applied
#       Mean: [0.4099649  0.49691623 0.7355861 ]..., Std: [0.18756151 0.23732135 0.21871617]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.011629 | Val=0.000950 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004346 | Val=0.000644 | LR=1.27e-04
#    Epoch 020/100 | Train=0.003015 | Val=0.002314 | LR=3.00e-04
#    Epoch 030/100 | Train=0.006235 | Val=0.002913 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002115 | Val=0.000251 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001096 | Val=0.000102 | LR=3.59e-05
#    Epoch 060/100 | Train=0.001866 | Val=0.000594 | LR=3.00e-04
#    Epoch 070/100 | Train=0.002782 | Val=0.000543 | LR=2.86e-04
#    Epoch 080/100 | Train=0.001456 | Val=0.000047 | LR=2.52e-04
#    Epoch 090/100 | Train=0.001322 | Val=0.000154 | LR=2.02e-04
#    Epoch 099/100 | Train=0.000771 | Val=0.000012 | LR=1.50e-04
#    ⏹️  Early stopping at epoch 99 (best val=0.000008)
#    ✅ Loaded best model (val loss: 0.000008)
#
#    📊 Test Metrics:
#       MAE:       4.044783e-06
#       Pearson r: 0.908 (p=2.759e-01)
#       R²:        -3.312
#       Horizon MAE: T0=5.60e-06, T1=4.70e-06, T2=1.84e-06
#    ⏱️  Fold time: 2.2 minutes
#
# ======================================================================
# FOLD 4/33 | Test: AR11429_X5.4
# ======================================================================
#    Train: 31 flares
#    Val:   AR11429_M6.3
#    Test:  AR11429_X5.4
#    🔍 Train-only normalization applied
#       Mean: [0.40963578 0.49650425 0.73540574]..., Std: [0.18757167 0.23773032 0.21898969]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.013576 | Val=0.000670 | LR=2.98e-04
#    Epoch 010/100 | Train=0.005808 | Val=0.000151 | LR=1.27e-04
#    Epoch 020/100 | Train=0.005630 | Val=0.007556 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003012 | Val=0.001354 | LR=2.47e-04
#    Epoch 040/100 | Train=0.001571 | Val=0.001497 | LR=1.38e-04
#    Epoch 050/100 | Train=0.000852 | Val=0.001831 | LR=3.59e-05
#    Epoch 060/100 | Train=0.001911 | Val=0.001547 | LR=3.00e-04
#    Epoch 070/100 | Train=0.002104 | Val=0.000209 | LR=2.86e-04
#    ⏹️  Early stopping at epoch 73 (best val=0.000038)
#    ✅ Loaded best model (val loss: 0.000038)
#
#    📊 Test Metrics:
#       MAE:       1.308138e-05
#       Pearson r: -0.713 (p=4.944e-01)
#       R²:        -66.801
#       Horizon MAE: T0=1.08e-05, T1=1.81e-05, T2=1.03e-05
#    ⏱️  Fold time: 1.6 minutes
#
# ======================================================================
# FOLD 5/33 | Test: AR11429_M6.3
# ======================================================================
#    Train: 31 flares
#    Val:   AR11520_X1.4
#    Test:  AR11429_M6.3
#    🔍 Train-only normalization applied
#       Mean: [0.41020858 0.49680477 0.73587835]..., Std: [0.18769968 0.23736668 0.21878484]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.015971 | Val=0.003203 | LR=2.98e-04
#    Epoch 010/100 | Train=0.006373 | Val=0.001432 | LR=1.27e-04
#    Epoch 020/100 | Train=0.003899 | Val=0.009768 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003500 | Val=0.003566 | LR=2.47e-04
#    Epoch 040/100 | Train=0.001754 | Val=0.001763 | LR=1.38e-04
#    Epoch 050/100 | Train=0.000955 | Val=0.003988 | LR=3.59e-05
#    Epoch 060/100 | Train=0.001272 | Val=0.004418 | LR=3.00e-04
#    Epoch 070/100 | Train=0.001511 | Val=0.002153 | LR=2.86e-04
#    Epoch 080/100 | Train=0.001688 | Val=0.002598 | LR=2.52e-04
#    ⏹️  Early stopping at epoch 87 (best val=0.000282)
#    ✅ Loaded best model (val loss: 0.000282)
#
#    📊 Test Metrics:
#       MAE:       3.761736e-06
#       Pearson r: -0.151 (p=9.037e-01)
#       R²:        -6.340
#       Horizon MAE: T0=2.11e-06, T1=6.43e-06, T2=2.74e-06
#    ⏱️  Fold time: 1.9 minutes
#
# ======================================================================
# FOLD 6/33 | Test: AR11520_X1.4
# ======================================================================
#    Train: 31 flares
#    Val:   AR11719_M6.5
#    Test:  AR11520_X1.4
#    🔍 Train-only normalization applied
#       Mean: [0.41028422 0.4965421  0.73673254]..., Std: [0.18736987 0.2378438  0.21903826]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.015166 | Val=0.007353 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004694 | Val=0.000855 | LR=1.27e-04
#    Epoch 020/100 | Train=0.007376 | Val=0.037494 | LR=3.00e-04
#    Epoch 030/100 | Train=0.004952 | Val=0.002047 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002375 | Val=0.000487 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001510 | Val=0.001966 | LR=3.59e-05
#    Epoch 060/100 | Train=0.000808 | Val=0.002671 | LR=3.00e-04
#    ⏹️  Early stopping at epoch 66 (best val=0.000224)
#    ✅ Loaded best model (val loss: 0.000224)
#
#    📊 Test Metrics:
#       MAE:       1.118126e-05
#       Pearson r: -0.956 (p=1.900e-01)
#       R²:        -15.563
#       Horizon MAE: T0=3.67e-06, T1=1.60e-05, T2=1.39e-05
#    ⏱️  Fold time: 1.5 minutes
#
# ======================================================================
# FOLD 7/33 | Test: AR11719_M6.5
# ======================================================================
#    Train: 31 flares
#    Val:   AR12036_M7.3
#    Test:  AR11719_M6.5
#    🔍 Train-only normalization applied
#       Mean: [0.41022205 0.49603832 0.73628575]..., Std: [0.18708502 0.23775283 0.21936446]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.010979 | Val=0.042238 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004295 | Val=0.000785 | LR=1.27e-04
#    Epoch 020/100 | Train=0.003823 | Val=0.001663 | LR=3.00e-04
#    Epoch 030/100 | Train=0.002411 | Val=0.000556 | LR=2.47e-04
#    Epoch 040/100 | Train=0.001638 | Val=0.005080 | LR=1.38e-04
#    Epoch 050/100 | Train=0.000982 | Val=0.003908 | LR=3.59e-05
#    Epoch 060/100 | Train=0.000735 | Val=0.003090 | LR=3.00e-04
#    Epoch 070/100 | Train=0.002308 | Val=0.003451 | LR=2.86e-04
#    Epoch 080/100 | Train=0.000896 | Val=0.003683 | LR=2.52e-04
#    Epoch 090/100 | Train=0.001074 | Val=0.000290 | LR=2.02e-04
#    Epoch 099/100 | Train=0.000834 | Val=0.005463 | LR=1.50e-04
#    ✅ Loaded best model (val loss: 0.000050)
#
#    📊 Test Metrics:
#       MAE:       2.398093e-06
#       Pearson r: 0.956 (p=1.894e-01)
#       R²:        0.106
#       Horizon MAE: T0=2.54e-06, T1=8.75e-07, T2=3.78e-06
#    ⏱️  Fold time: 2.2 minutes
#
# ======================================================================
# FOLD 8/33 | Test: AR12036_M7.3
# ======================================================================
#    Train: 31 flares
#    Val:   AR11944_X1.2
#    Test:  AR12036_M7.3
#    🔍 Train-only normalization applied
#       Mean: [0.41015187 0.4957625  0.7352266 ]..., Std: [0.18708499 0.23718342 0.2193694 ]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.009885 | Val=0.037285 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004818 | Val=0.001538 | LR=1.27e-04
#    Epoch 020/100 | Train=0.003029 | Val=0.001463 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003349 | Val=0.000979 | LR=2.47e-04
#    Epoch 040/100 | Train=0.001507 | Val=0.002341 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001711 | Val=0.000761 | LR=3.59e-05
#    Epoch 060/100 | Train=0.002236 | Val=0.000636 | LR=3.00e-04
#    ⏹️  Early stopping at epoch 66 (best val=0.000145)
#    ✅ Loaded best model (val loss: 0.000145)
#
#    📊 Test Metrics:
#       MAE:       1.453513e-05
#       Pearson r: 0.082 (p=9.476e-01)
#       R²:        -331.390
#       Horizon MAE: T0=1.49e-05, T1=1.27e-05, T2=1.59e-05
#    ⏱️  Fold time: 1.5 minutes
#
# ======================================================================
# FOLD 9/33 | Test: AR11944_X1.2
# ======================================================================
#    Train: 31 flares
#    Val:   AR12017_X1.0
#    Test:  AR11944_X1.2
#    🔍 Train-only normalization applied
#       Mean: [0.41008508 0.49567586 0.73517936]..., Std: [0.18732388 0.23736203 0.219519  ]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.010741 | Val=0.046163 | LR=2.98e-04
#    Epoch 010/100 | Train=0.003728 | Val=0.003710 | LR=1.27e-04
#    Epoch 020/100 | Train=0.003132 | Val=0.006225 | LR=3.00e-04
#    Epoch 030/100 | Train=0.001509 | Val=0.012330 | LR=2.47e-04
#    Epoch 040/100 | Train=0.001102 | Val=0.009937 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001008 | Val=0.008648 | LR=3.59e-05
#    Epoch 060/100 | Train=0.001312 | Val=0.005546 | LR=3.00e-04
#    Epoch 070/100 | Train=0.002185 | Val=0.000847 | LR=2.86e-04
#    ⏹️  Early stopping at epoch 72 (best val=0.000398)
#    ✅ Loaded best model (val loss: 0.000398)
#
#    📊 Test Metrics:
#       MAE:       7.365292e-06
#       Pearson r: -0.027 (p=9.831e-01)
#       R²:        -9.123
#       Horizon MAE: T0=2.37e-06, T1=1.32e-05, T2=6.53e-06
#    ⏱️  Fold time: 1.6 minutes
#
# ======================================================================
# FOLD 10/33 | Test: AR12017_X1.0
# ======================================================================
#    Train: 31 flares
#    Val:   AR11166_X1.5
#    Test:  AR12017_X1.0
#    🔍 Train-only normalization applied
#       Mean: [0.4110251  0.49623385 0.7348506 ]..., Std: [0.18778996 0.2374791  0.21939306]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.017392 | Val=0.002744 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004990 | Val=0.004128 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004661 | Val=0.000317 | LR=3.00e-04
#    Epoch 030/100 | Train=0.004567 | Val=0.001445 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002649 | Val=0.001183 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001322 | Val=0.000059 | LR=3.59e-05
#    Epoch 060/100 | Train=0.001883 | Val=0.002243 | LR=3.00e-04
#    ⏹️  Early stopping at epoch 62 (best val=0.000004)
#    ✅ Loaded best model (val loss: 0.000004)
#
#    📊 Test Metrics:
#       MAE:       2.584038e-05
#       Pearson r: -0.992 (p=7.804e-02)
#       R²:        -471.719
#       Horizon MAE: T0=1.89e-05, T1=2.75e-05, T2=3.11e-05
#    ⏱️  Fold time: 1.4 minutes
#
# ======================================================================
# FOLD 11/33 | Test: AR11166_X1.5
# ======================================================================
#    Train: 31 flares
#    Val:   AR11261_M6.0
#    Test:  AR11166_X1.5
#    🔍 Train-only normalization applied
#       Mean: [0.41113436 0.49691275 0.7350519 ]..., Std: [0.18793423 0.23726697 0.21890537]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.015623 | Val=0.005852 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004910 | Val=0.001166 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004596 | Val=0.000370 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003293 | Val=0.000676 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002295 | Val=0.000461 | LR=1.38e-04
#    Epoch 050/100 | Train=0.002619 | Val=0.000398 | LR=3.59e-05
#    Epoch 060/100 | Train=0.001801 | Val=0.000328 | LR=3.00e-04
#    Epoch 070/100 | Train=0.002305 | Val=0.002534 | LR=2.86e-04
#    Epoch 080/100 | Train=0.002233 | Val=0.000001 | LR=2.52e-04
#    Epoch 090/100 | Train=0.002519 | Val=0.003932 | LR=2.02e-04
#    Epoch 099/100 | Train=0.001040 | Val=0.000352 | LR=1.50e-04
#    ✅ Loaded best model (val loss: 0.000001)
#
#    📊 Test Metrics:
#       MAE:       5.242699e-06
#       Pearson r: 0.290 (p=8.128e-01)
#       R²:        -3.819
#       Horizon MAE: T0=7.95e-06, T1=6.10e-06, T2=1.68e-06
#    ⏱️  Fold time: 2.2 minutes
#
# ======================================================================
# FOLD 12/33 | Test: AR11261_M6.0
# ======================================================================
#    Train: 31 flares
#    Val:   AR11261_M9.3b
#    Test:  AR11261_M6.0
#    🔍 Train-only normalization applied
#       Mean: [0.41090196 0.49730885 0.73563486]..., Std: [0.18803301 0.23690744 0.21868141]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.010010 | Val=0.065238 | LR=2.98e-04
#    Epoch 010/100 | Train=0.005263 | Val=0.001463 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004424 | Val=0.001996 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003796 | Val=0.000712 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002994 | Val=0.008242 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001941 | Val=0.000150 | LR=3.59e-05
#    Epoch 060/100 | Train=0.001737 | Val=0.008526 | LR=3.00e-04
#    ⏹️  Early stopping at epoch 65 (best val=0.000041)
#    ✅ Loaded best model (val loss: 0.000041)
#
#    📊 Test Metrics:
#       MAE:       1.835106e-06
#       Pearson r: 0.721 (p=4.871e-01)
#       R²:        -8.733
#       Horizon MAE: T0=1.80e-06, T1=2.42e-06, T2=1.29e-06
#    ⏱️  Fold time: 1.5 minutes
#
# ======================================================================
# FOLD 13/33 | Test: AR11261_M9.3b
# ======================================================================
#    Train: 31 flares
#    Val:   AR11283_M5.3
#    Test:  AR11261_M9.3b
#    🔍 Train-only normalization applied
#       Mean: [0.4114388  0.49752814 0.73586464]..., Std: [0.18822281 0.23720941 0.21886669]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.011224 | Val=0.002703 | LR=2.98e-04
#    Epoch 010/100 | Train=0.005721 | Val=0.001364 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004105 | Val=0.000329 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003029 | Val=0.000329 | LR=2.47e-04
#    Epoch 040/100 | Train=0.001524 | Val=0.001124 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001277 | Val=0.001376 | LR=3.59e-05
#    Epoch 060/100 | Train=0.001330 | Val=0.000957 | LR=3.00e-04
#    Epoch 070/100 | Train=0.001972 | Val=0.002264 | LR=2.86e-04
#    Epoch 080/100 | Train=0.001075 | Val=0.001013 | LR=2.52e-04
#    ⏹️  Early stopping at epoch 87 (best val=0.000067)
#    ✅ Loaded best model (val loss: 0.000067)
#
#    📊 Test Metrics:
#       MAE:       1.926475e-06
#       Pearson r: -0.963 (p=1.745e-01)
#       R²:        -2.616
#       Horizon MAE: T0=3.71e-06, T1=9.75e-07, T2=1.10e-06
#    ⏱️  Fold time: 2.0 minutes
#
# ======================================================================
# FOLD 14/33 | Test: AR11283_M5.3
# ======================================================================
#    Train: 31 flares
#    Val:   AR11283_X2.1
#    Test:  AR11283_M5.3
#    🔍 Train-only normalization applied
#       Mean: [0.41152573 0.49787736 0.73625255]..., Std: [0.18824646 0.23764993 0.21897219]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.017274 | Val=0.010474 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004496 | Val=0.000628 | LR=1.27e-04
#    Epoch 020/100 | Train=0.003550 | Val=0.001592 | LR=3.00e-04
#    Epoch 030/100 | Train=0.002118 | Val=0.003620 | LR=2.47e-04
#    Epoch 040/100 | Train=0.001697 | Val=0.000319 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001079 | Val=0.001209 | LR=3.59e-05
#    Epoch 060/100 | Train=0.000913 | Val=0.001471 | LR=3.00e-04
#    Epoch 070/100 | Train=0.001960 | Val=0.000413 | LR=2.86e-04
#    Epoch 080/100 | Train=0.001151 | Val=0.000437 | LR=2.52e-04
#    ⏹️  Early stopping at epoch 84 (best val=0.000040)
#    ✅ Loaded best model (val loss: 0.000040)
#
#    📊 Test Metrics:
#       MAE:       8.328643e-07
#       Pearson r: 0.982 (p=1.193e-01)
#       R²:        0.800
#       Horizon MAE: T0=4.53e-07, T1=5.73e-08, T2=1.99e-06
#    ⏱️  Fold time: 1.9 minutes
#
# ======================================================================
# FOLD 15/33 | Test: AR11283_X2.1
# ======================================================================
#    Train: 31 flares
#    Val:   AR11283_X1.8
#    Test:  AR11283_X2.1
#    🔍 Train-only normalization applied
#       Mean: [0.41128486 0.49820998 0.7364317 ]..., Std: [0.18825732 0.23787472 0.21892798]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.018298 | Val=0.004397 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004184 | Val=0.002829 | LR=1.27e-04
#    Epoch 020/100 | Train=0.003731 | Val=0.001932 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003964 | Val=0.000048 | LR=2.47e-04
#    Epoch 040/100 | Train=0.001337 | Val=0.001659 | LR=1.38e-04
#    Epoch 050/100 | Train=0.000923 | Val=0.000747 | LR=3.59e-05
#    Epoch 060/100 | Train=0.001084 | Val=0.001176 | LR=3.00e-04
#    Epoch 070/100 | Train=0.001836 | Val=0.000090 | LR=2.86e-04
#    Epoch 080/100 | Train=0.001189 | Val=0.000398 | LR=2.52e-04
#    Epoch 090/100 | Train=0.001130 | Val=0.000412 | LR=2.02e-04
#    Epoch 099/100 | Train=0.000616 | Val=0.000676 | LR=1.50e-04
#    ✅ Loaded best model (val loss: 0.000029)
#
#    📊 Test Metrics:
#       MAE:       2.524085e-06
#       Pearson r: 0.407 (p=7.333e-01)
#       R²:        0.059
#       Horizon MAE: T0=3.01e-06, T1=2.02e-06, T2=2.54e-06
#    ⏱️  Fold time: 2.2 minutes
#
# ======================================================================
# FOLD 16/33 | Test: AR11283_X1.8
# ======================================================================
#    Train: 31 flares
#    Val:   AR11283_M6.7
#    Test:  AR11283_X1.8
#    🔍 Train-only normalization applied
#       Mean: [0.4108922 0.4981278 0.7360808]..., Std: [0.18815216 0.2377841  0.21898168]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.014013 | Val=0.026686 | LR=2.98e-04
#    Epoch 010/100 | Train=0.005503 | Val=0.000126 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004003 | Val=0.000174 | LR=3.00e-04
#    Epoch 030/100 | Train=0.006035 | Val=0.007080 | LR=2.47e-04
#    Epoch 040/100 | Train=0.003879 | Val=0.001039 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001319 | Val=0.007443 | LR=3.59e-05
#    ⏹️  Early stopping at epoch 59 (best val=0.000047)
#    ✅ Loaded best model (val loss: 0.000047)
#
#    📊 Test Metrics:
#       MAE:       2.006076e-06
#       Pearson r: -0.762 (p=4.484e-01)
#       R²:        -1.176
#       Horizon MAE: T0=2.81e-06, T1=1.70e-06, T2=1.50e-06
#    ⏱️  Fold time: 1.4 minutes
#
# ======================================================================
# FOLD 17/33 | Test: AR11283_M6.7
# ======================================================================
#    Train: 31 flares
#    Val:   AR11302_M7.4
#    Test:  AR11283_M6.7
#    🔍 Train-only normalization applied
#       Mean: [0.41092792 0.49733213 0.73564595]..., Std: [0.18790555 0.23762247 0.21913244]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.012081 | Val=0.006179 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004535 | Val=0.004135 | LR=1.27e-04
#    Epoch 020/100 | Train=0.005288 | Val=0.024095 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003074 | Val=0.005693 | LR=2.47e-04
#    Epoch 040/100 | Train=0.001571 | Val=0.002457 | LR=1.38e-04
#    Epoch 050/100 | Train=0.000973 | Val=0.001772 | LR=3.59e-05
#    ⏹️  Early stopping at epoch 57 (best val=0.000314)
#    ✅ Loaded best model (val loss: 0.000314)
#
#    📊 Test Metrics:
#       MAE:       6.861910e-06
#       Pearson r: 0.210 (p=8.653e-01)
#       R²:        -14.097
#       Horizon MAE: T0=7.94e-06, T1=3.16e-06, T2=9.49e-06
#    ⏱️  Fold time: 1.3 minutes
#
# ======================================================================
# FOLD 18/33 | Test: AR11302_M7.4
# ======================================================================
#    Train: 31 flares
#    Val:   AR11402_M8.7
#    Test:  AR11302_M7.4
#    🔍 Train-only normalization applied
#       Mean: [0.41085872 0.4966499  0.7360304 ]..., Std: [0.18763514 0.2377995  0.21912973]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.014128 | Val=0.002041 | LR=2.98e-04
#    Epoch 010/100 | Train=0.005508 | Val=0.000938 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004749 | Val=0.002853 | LR=3.00e-04
#    Epoch 030/100 | Train=0.004098 | Val=0.000427 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002203 | Val=0.000943 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001637 | Val=0.000164 | LR=3.59e-05
#    Epoch 060/100 | Train=0.001141 | Val=0.000452 | LR=3.00e-04
#    Epoch 070/100 | Train=0.002733 | Val=0.001053 | LR=2.86e-04
#    ⏹️  Early stopping at epoch 75 (best val=0.000033)
#    ✅ Loaded best model (val loss: 0.000033)
#
#    📊 Test Metrics:
#       MAE:       3.969799e-06
#       Pearson r: 0.597 (p=5.925e-01)
#       R²:        0.156
#       Horizon MAE: T0=7.51e-06, T1=4.90e-07, T2=3.91e-06
#    ⏱️  Fold time: 1.7 minutes
#
# ======================================================================
# FOLD 19/33 | Test: AR11402_M8.7
# ======================================================================
#    Train: 31 flares
#    Val:   AR11429_X1.3
#    Test:  AR11402_M8.7
#    🔍 Train-only normalization applied
#       Mean: [0.40999362 0.49598676 0.7359213 ]..., Std: [0.18760514 0.23794526 0.21906227]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.010816 | Val=0.002327 | LR=2.98e-04
#    Epoch 010/100 | Train=0.009357 | Val=0.002796 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004817 | Val=0.031479 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003750 | Val=0.004226 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002033 | Val=0.001482 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001437 | Val=0.000708 | LR=3.59e-05
#    Epoch 060/100 | Train=0.001338 | Val=0.000182 | LR=3.00e-04
#    ⏹️  Early stopping at epoch 67 (best val=0.000037)
#    ✅ Loaded best model (val loss: 0.000037)
#
#    📊 Test Metrics:
#       MAE:       6.593541e-06
#       Pearson r: -0.197 (p=8.735e-01)
#       R²:        -103.101
#       Horizon MAE: T0=4.86e-06, T1=4.70e-06, T2=1.02e-05
#    ⏱️  Fold time: 1.5 minutes
#
# ======================================================================
# FOLD 20/33 | Test: AR11429_X1.3
# ======================================================================
#    Train: 31 flares
#    Val:   AR11429_M8.4
#    Test:  AR11429_X1.3
#    🔍 Train-only normalization applied
#       Mean: [0.41012648 0.49594167 0.7354152 ]..., Std: [0.18785155 0.23765603 0.21905693]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.015110 | Val=0.018213 | LR=2.98e-04
#    Epoch 010/100 | Train=0.006030 | Val=0.000358 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004432 | Val=0.002904 | LR=3.00e-04
#    Epoch 030/100 | Train=0.002234 | Val=0.000849 | LR=2.47e-04
#    Epoch 040/100 | Train=0.001828 | Val=0.000122 | LR=1.38e-04
#    Epoch 050/100 | Train=0.000782 | Val=0.000434 | LR=3.59e-05
#    Epoch 060/100 | Train=0.001077 | Val=0.000127 | LR=3.00e-04
#    Epoch 070/100 | Train=0.001952 | Val=0.000330 | LR=2.86e-04
#    Epoch 080/100 | Train=0.002037 | Val=0.000402 | LR=2.52e-04
#    Epoch 090/100 | Train=0.000954 | Val=0.001544 | LR=2.02e-04
#    Epoch 099/100 | Train=0.000545 | Val=0.000493 | LR=1.50e-04
#    ✅ Loaded best model (val loss: 0.000049)
#
#    📊 Test Metrics:
#       MAE:       2.341680e-06
#       Pearson r: 0.925 (p=2.488e-01)
#       R²:        -1.173
#       Horizon MAE: T0=2.30e-06, T1=1.58e-06, T2=3.15e-06
#    ⏱️  Fold time: 2.2 minutes
#
# ======================================================================
# FOLD 21/33 | Test: AR11429_M8.4
# ======================================================================
#    Train: 31 flares
#    Val:   AR11476_M5.7
#    Test:  AR11429_M8.4
#    🔍 Train-only normalization applied
#       Mean: [0.41097155 0.49682462 0.7355601 ]..., Std: [0.18793327 0.23751812 0.21910955]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.014013 | Val=0.002611 | LR=2.98e-04
#    Epoch 010/100 | Train=0.005865 | Val=0.001286 | LR=1.27e-04
#    Epoch 020/100 | Train=0.006692 | Val=0.003375 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003248 | Val=0.000715 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002085 | Val=0.000649 | LR=1.38e-04
#    Epoch 050/100 | Train=0.000781 | Val=0.000892 | LR=3.59e-05
#    Epoch 060/100 | Train=0.000869 | Val=0.000997 | LR=3.00e-04
#    Epoch 070/100 | Train=0.003352 | Val=0.000703 | LR=2.86e-04
#    Epoch 080/100 | Train=0.001667 | Val=0.001146 | LR=2.52e-04
#    Epoch 090/100 | Train=0.000713 | Val=0.000491 | LR=2.02e-04
#    Epoch 099/100 | Train=0.001118 | Val=0.000381 | LR=1.50e-04
#    ✅ Loaded best model (val loss: 0.000006)
#
#    📊 Test Metrics:
#       MAE:       1.874146e-06
#       Pearson r: 0.771 (p=4.394e-01)
#       R²:        -0.267
#       Horizon MAE: T0=2.97e-06, T1=2.59e-08, T2=2.63e-06
#    ⏱️  Fold time: 2.3 minutes
#
# ======================================================================
# FOLD 22/33 | Test: AR11476_M5.7
# ======================================================================
#    Train: 31 flares
#    Val:   AR11515_M5.6
#    Test:  AR11476_M5.7
#    🔍 Train-only normalization applied
#       Mean: [0.41086257 0.49705338 0.7358882 ]..., Std: [0.18763742 0.23733804 0.21903011]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.011584 | Val=0.004327 | LR=2.98e-04
#    Epoch 010/100 | Train=0.005007 | Val=0.002643 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004433 | Val=0.002841 | LR=3.00e-04
#    Epoch 030/100 | Train=0.004890 | Val=0.001232 | LR=2.47e-04
#    Epoch 040/100 | Train=0.001985 | Val=0.002332 | LR=1.38e-04
#    Epoch 050/100 | Train=0.000998 | Val=0.001435 | LR=3.59e-05
#    Epoch 060/100 | Train=0.001383 | Val=0.001990 | LR=3.00e-04
#    Epoch 070/100 | Train=0.001620 | Val=0.003698 | LR=2.86e-04
#    ⏹️  Early stopping at epoch 72 (best val=0.000385)
#    ✅ Loaded best model (val loss: 0.000385)
#
#    📊 Test Metrics:
#       MAE:       3.079008e-06
#       Pearson r: 0.000 (p=9.999e-01)
#       R²:        -44.482
#       Horizon MAE: T0=2.19e-07, T1=1.94e-06, T2=7.07e-06
#    ⏱️  Fold time: 1.7 minutes
#
# ======================================================================
# FOLD 23/33 | Test: AR11515_M5.6
# ======================================================================
#    Train: 31 flares
#    Val:   AR11515_M5.3
#    Test:  AR11515_M5.6
#    🔍 Train-only normalization applied
#       Mean: [0.41122526 0.49724215 0.7363821 ]..., Std: [0.18762754 0.23735884 0.21900547]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.013494 | Val=0.041513 | LR=2.98e-04
#    Epoch 010/100 | Train=0.005988 | Val=0.001064 | LR=1.27e-04
#    Epoch 020/100 | Train=0.005042 | Val=0.004272 | LR=3.00e-04
#    Epoch 030/100 | Train=0.004223 | Val=0.002483 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002120 | Val=0.002422 | LR=1.38e-04
#    Epoch 050/100 | Train=0.000684 | Val=0.001727 | LR=3.59e-05
#    ⏹️  Early stopping at epoch 58 (best val=0.000046)
#    ✅ Loaded best model (val loss: 0.000046)
#
#    📊 Test Metrics:
#       MAE:       7.154000e-06
#       Pearson r: 0.179 (p=8.854e-01)
#       R²:        -0.505
#       Horizon MAE: T0=8.85e-06, T1=8.25e-06, T2=4.36e-06
#    ⏱️  Fold time: 1.3 minutes
#
# ======================================================================
# FOLD 24/33 | Test: AR11515_M5.3
# ======================================================================
#    Train: 31 flares
#    Val:   AR11515_M6.1
#    Test:  AR11515_M5.3
#    🔍 Train-only normalization applied
#       Mean: [0.4119335  0.4976868  0.73669666]..., Std: [0.18777119 0.2377182  0.2191795 ]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.010436 | Val=0.002106 | LR=2.98e-04
#    Epoch 010/100 | Train=0.005469 | Val=0.000344 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004571 | Val=0.000729 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003089 | Val=0.000342 | LR=2.47e-04
#    Epoch 040/100 | Train=0.001911 | Val=0.002997 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001338 | Val=0.000755 | LR=3.59e-05
#    ⏹️  Early stopping at epoch 59 (best val=0.000023)
#    ✅ Loaded best model (val loss: 0.000023)
#
#    📊 Test Metrics:
#       MAE:       3.004568e-06
#       Pearson r: -0.683 (p=5.211e-01)
#       R²:        -3.372
#       Horizon MAE: T0=4.67e-06, T1=1.58e-06, T2=2.76e-06
#    ⏱️  Fold time: 1.4 minutes
#
# ======================================================================
# FOLD 25/33 | Test: AR11515_M6.1
# ======================================================================
#    Train: 31 flares
#    Val:   AR11877_M9.3
#    Test:  AR11515_M6.1
#    🔍 Train-only normalization applied
#       Mean: [0.41094008 0.4969909  0.7360485 ]..., Std: [0.18748888 0.23750083 0.21938138]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.009223 | Val=0.033960 | LR=2.98e-04
#    Epoch 010/100 | Train=0.005880 | Val=0.000327 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004752 | Val=0.003000 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003407 | Val=0.000188 | LR=2.47e-04
#    Epoch 040/100 | Train=0.001663 | Val=0.002483 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001003 | Val=0.005771 | LR=3.59e-05
#    Epoch 060/100 | Train=0.001051 | Val=0.000671 | LR=3.00e-04
#    Epoch 070/100 | Train=0.002622 | Val=0.014695 | LR=2.86e-04
#    ⏹️  Early stopping at epoch 75 (best val=0.000091)
#    ✅ Loaded best model (val loss: 0.000091)
#
#    📊 Test Metrics:
#       MAE:       7.792354e-06
#       Pearson r: -0.337 (p=7.809e-01)
#       R²:        -18.712
#       Horizon MAE: T0=1.34e-05, T1=5.31e-06, T2=4.71e-06
#    ⏱️  Fold time: 1.7 minutes
#
# ======================================================================
# FOLD 26/33 | Test: AR11877_M9.3
# ======================================================================
#    Train: 31 flares
#    Val:   AR11884_M6.3
#    Test:  AR11877_M9.3
#    🔍 Train-only normalization applied
#       Mean: [0.41018945 0.4960123  0.7351947 ]..., Std: [0.18747473 0.23747012 0.21942365]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.013556 | Val=0.015286 | LR=2.98e-04
#    Epoch 010/100 | Train=0.005127 | Val=0.000638 | LR=1.27e-04
#    Epoch 020/100 | Train=0.003860 | Val=0.020315 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003408 | Val=0.009811 | LR=2.47e-04
#    Epoch 040/100 | Train=0.001680 | Val=0.013128 | LR=1.38e-04
#    Epoch 050/100 | Train=0.000835 | Val=0.001521 | LR=3.59e-05
#    ⏹️  Early stopping at epoch 58 (best val=0.000071)
#    ✅ Loaded best model (val loss: 0.000071)
#
#    📊 Test Metrics:
#       MAE:       2.346111e-06
#       Pearson r: 0.065 (p=9.587e-01)
#       R²:        -0.247
#       Horizon MAE: T0=4.47e-06, T1=2.01e-06, T2=5.57e-07
#    ⏱️  Fold time: 1.3 minutes
#
# ======================================================================
# FOLD 27/33 | Test: AR11884_M6.3
# ======================================================================
#    Train: 31 flares
#    Val:   AR11884_M5.0
#    Test:  AR11884_M6.3
#    🔍 Train-only normalization applied
#       Mean: [0.4104367 0.4961601 0.7353889]..., Std: [0.18763188 0.23781447 0.21934034]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.015034 | Val=0.001544 | LR=2.98e-04
#    Epoch 010/100 | Train=0.006104 | Val=0.001837 | LR=1.27e-04
#    Epoch 020/100 | Train=0.003361 | Val=0.017168 | LR=3.00e-04
#    Epoch 030/100 | Train=0.003341 | Val=0.005330 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002104 | Val=0.003310 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001275 | Val=0.002196 | LR=3.59e-05
#    ⏹️  Early stopping at epoch 54 (best val=0.000155)
#    ✅ Loaded best model (val loss: 0.000155)
#
#    📊 Test Metrics:
#       MAE:       4.566823e-06
#       Pearson r: -0.913 (p=2.679e-01)
#       R²:        -52.938
#       Horizon MAE: T0=2.17e-06, T1=3.36e-06, T2=8.17e-06
#    ⏱️  Fold time: 1.2 minutes
#
# ======================================================================
# FOLD 28/33 | Test: AR11884_M5.0
# ======================================================================
#    Train: 31 flares
#    Val:   AR11890_X1.1a
#    Test:  AR11884_M5.0
#    🔍 Train-only normalization applied
#       Mean: [0.41039008 0.49644414 0.73558915]..., Std: [0.1876121  0.23775083 0.21945663]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.012997 | Val=0.003362 | LR=2.98e-04
#    Epoch 010/100 | Train=0.007418 | Val=0.002345 | LR=1.27e-04
#    Epoch 020/100 | Train=0.003261 | Val=0.001101 | LR=3.00e-04
#    Epoch 030/100 | Train=0.002681 | Val=0.002121 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002613 | Val=0.001086 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001252 | Val=0.000596 | LR=3.59e-05
#    Epoch 060/100 | Train=0.001913 | Val=0.000419 | LR=3.00e-04
#    Epoch 070/100 | Train=0.002656 | Val=0.002047 | LR=2.86e-04
#    ⏹️  Early stopping at epoch 77 (best val=0.000285)
#    ✅ Loaded best model (val loss: 0.000285)
#
#    📊 Test Metrics:
#       MAE:       9.445488e-06
#       Pearson r: 0.843 (p=3.614e-01)
#       R²:        -341.375
#       Horizon MAE: T0=8.75e-06, T1=9.31e-06, T2=1.03e-05
#    ⏱️  Fold time: 1.7 minutes
#
# ======================================================================
# FOLD 29/33 | Test: AR11890_X1.1a
# ======================================================================
#    Train: 31 flares
#    Val:   AR11890_X1.1b
#    Test:  AR11890_X1.1a
#    🔍 Train-only normalization applied
#       Mean: [0.41055518 0.49644256 0.73574257]..., Std: [0.1876512  0.23776063 0.21948552]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.017392 | Val=0.015283 | LR=2.98e-04
#    Epoch 010/100 | Train=0.007460 | Val=0.002440 | LR=1.27e-04
#    Epoch 020/100 | Train=0.003075 | Val=0.005652 | LR=3.00e-04
#    Epoch 030/100 | Train=0.004011 | Val=0.001489 | LR=2.47e-04
#    Epoch 040/100 | Train=0.002481 | Val=0.002246 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001249 | Val=0.003681 | LR=3.59e-05
#    ⏹️  Early stopping at epoch 52 (best val=0.000157)
#    ✅ Loaded best model (val loss: 0.000157)
#
#    📊 Test Metrics:
#       MAE:       3.560213e-06
#       Pearson r: 0.489 (p=6.750e-01)
#       R²:        -1.063
#       Horizon MAE: T0=2.73e-06, T1=1.75e-07, T2=7.77e-06
#    ⏱️  Fold time: 1.2 minutes
#
# ======================================================================
# FOLD 30/33 | Test: AR11890_X1.1b
# ======================================================================
#    Train: 31 flares
#    Val:   AR11936_M6.4
#    Test:  AR11890_X1.1b
#    🔍 Train-only normalization applied
#       Mean: [0.41120538 0.49632877 0.73548484]..., Std: [0.18779269 0.23783326 0.21949983]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.015287 | Val=0.004908 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004354 | Val=0.001055 | LR=1.27e-04
#    Epoch 020/100 | Train=0.003711 | Val=0.001566 | LR=3.00e-04
#    Epoch 030/100 | Train=0.002889 | Val=0.001955 | LR=2.47e-04
#    Epoch 040/100 | Train=0.001752 | Val=0.001121 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001697 | Val=0.002810 | LR=3.59e-05
#    Epoch 060/100 | Train=0.001014 | Val=0.002621 | LR=3.00e-04
#    ⏹️  Early stopping at epoch 62 (best val=0.000448)
#    ✅ Loaded best model (val loss: 0.000448)
#
#    📊 Test Metrics:
#       MAE:       1.332252e-06
#       Pearson r: 0.413 (p=7.291e-01)
#       R²:        0.080
#       Horizon MAE: T0=2.81e-06, T1=1.87e-07, T2=1.00e-06
#    ⏱️  Fold time: 1.4 minutes
#
# ======================================================================
# FOLD 31/33 | Test: AR11936_M6.4
# ======================================================================
#    Train: 31 flares
#    Val:   AR11944_M7.2
#    Test:  AR11936_M6.4
#    🔍 Train-only normalization applied
#       Mean: [0.4107669  0.49572292 0.7349762 ]..., Std: [0.18756706 0.23751177 0.21954332]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.010084 | Val=0.001557 | LR=2.98e-04
#    Epoch 010/100 | Train=0.005133 | Val=0.000993 | LR=1.27e-04
#    Epoch 020/100 | Train=0.007074 | Val=0.001945 | LR=3.00e-04
#    Epoch 030/100 | Train=0.005764 | Val=0.002206 | LR=2.47e-04
#    Epoch 040/100 | Train=0.001139 | Val=0.002306 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001060 | Val=0.001945 | LR=3.59e-05
#    Epoch 060/100 | Train=0.000904 | Val=0.007863 | LR=3.00e-04
#    Epoch 070/100 | Train=0.002482 | Val=0.008968 | LR=2.86e-04
#    Epoch 080/100 | Train=0.002524 | Val=0.000770 | LR=2.52e-04
#    ⏹️  Early stopping at epoch 84 (best val=0.000094)
#    ✅ Loaded best model (val loss: 0.000094)
#
#    📊 Test Metrics:
#       MAE:       3.966406e-06
#       Pearson r: 0.976 (p=1.387e-01)
#       R²:        -1.154
#       Horizon MAE: T0=1.17e-07, T1=4.61e-06, T2=7.17e-06
#    ⏱️  Fold time: 1.9 minutes
#
# ======================================================================
# FOLD 32/33 | Test: AR11944_M7.2
# ======================================================================
#    Train: 31 flares
#    Val:   AR12035_X1.3
#    Test:  AR11944_M7.2
#    🔍 Train-only normalization applied
#       Mean: [0.41002974 0.49540862 0.73495024]..., Std: [0.18747808 0.23730096 0.21949024]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.012309 | Val=0.021345 | LR=2.98e-04
#    Epoch 010/100 | Train=0.007153 | Val=0.000311 | LR=1.27e-04
#    Epoch 020/100 | Train=0.004392 | Val=0.000349 | LR=3.00e-04
#    Epoch 030/100 | Train=0.005643 | Val=0.002966 | LR=2.47e-04
#    Epoch 040/100 | Train=0.003049 | Val=0.002171 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001502 | Val=0.009692 | LR=3.59e-05
#    Epoch 060/100 | Train=0.003179 | Val=0.000174 | LR=3.00e-04
#    Epoch 070/100 | Train=0.001988 | Val=0.003048 | LR=2.86e-04
#    Epoch 080/100 | Train=0.002906 | Val=0.000838 | LR=2.52e-04
#    Epoch 090/100 | Train=0.001562 | Val=0.000793 | LR=2.02e-04
#    Epoch 099/100 | Train=0.000677 | Val=0.001622 | LR=1.50e-04
#    ✅ Loaded best model (val loss: 0.000174)
#
#    📊 Test Metrics:
#       MAE:       2.102800e-06
#       Pearson r: 0.915 (p=2.651e-01)
#       R²:        0.229
#       Horizon MAE: T0=2.06e-06, T1=7.66e-07, T2=3.48e-06
#    ⏱️  Fold time: 2.2 minutes
#
# ======================================================================
# FOLD 33/33 | Test: AR12035_X1.3
# ======================================================================
#    Train: 31 flares
#    Val:   AR11158_M6.6
#    Test:  AR12035_X1.3
#    🔍 Train-only normalization applied
#       Mean: [0.40966615 0.49611732 0.73509085]..., Std: [0.18752083 0.23738554 0.21899392]...
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.016919 | Val=0.021114 | LR=2.98e-04
#    Epoch 010/100 | Train=0.004106 | Val=0.006359 | LR=1.27e-04
#    Epoch 020/100 | Train=0.003045 | Val=0.010496 | LR=3.00e-04
#    Epoch 030/100 | Train=0.004211 | Val=0.002441 | LR=2.47e-04
#    Epoch 040/100 | Train=0.001971 | Val=0.004284 | LR=1.38e-04
#    Epoch 050/100 | Train=0.001025 | Val=0.005822 | LR=3.59e-05
#    Epoch 060/100 | Train=0.000980 | Val=0.001035 | LR=3.00e-04
#    Epoch 070/100 | Train=0.001430 | Val=0.001856 | LR=2.86e-04
#    Epoch 080/100 | Train=0.001776 | Val=0.000223 | LR=2.52e-04
#    Epoch 090/100 | Train=0.000975 | Val=0.003539 | LR=2.02e-04
#    Epoch 099/100 | Train=0.000964 | Val=0.001959 | LR=1.50e-04
#    ✅ Loaded best model (val loss: 0.000089)
#
#    📊 Test Metrics:
#       MAE:       4.628249e-06
#       Pearson r: -0.670 (p=5.326e-01)
#       R²:        -2.145
#       Horizon MAE: T0=5.13e-07, T1=4.65e-06, T2=8.72e-06
#    ⏱️  Fold time: 2.2 minutes
#
# ======================================================================
# LOFO COMPLETE - AIA-ONLY BASELINE (SAFELY NORMALIZED)
# ======================================================================
# Total time: 56.8 minutes (0.9 hours)
# Avg per fold: 1.7 minutes
#
# SUMMARY STATISTICS:
#   MAE: 5.377884e-06 ± 4.906262e-06
#   R² : -46.092 ± 110.074
# ✅ SAFE RESULTS SAVED to results_aia_only/

# %%
# %% DONT USE
# ============================================================
# CELL 8: CORRECTED LOFO CROSS-VALIDATION (AIA-ONLY)
# ============================================================
import csv

os.makedirs("results_aia_only", exist_ok=True)  # ← CHANGED folder name
results = []

print("\n" + "="*70)
print("LOFO CROSS-VALIDATION - AIA-ONLY BASELINE")  # ← CHANGED title
print("="*70)
print(f"Total flares: {len(flare_ids)}")
print(f"Channels: {IMG_CHANNELS} (AIA EUV/UV only)")  # ← ADDED
print(f"Train/Val/Test split: {len(flare_ids)-2} / 1 / 1 per fold")
print("="*70)

total_start_time = time.time()

for test_idx, test_flare in enumerate(flare_ids):
    fold_start_time = time.time()
    
    print(f"\n{'='*70}")
    print(f"FOLD {test_idx + 1}/{len(flare_ids)} | Test: {test_flare}")
    print(f"{'='*70}")
    
    # Create masks
    test_mask = np.zeros(len(X), dtype=bool)
    test_mask[test_idx] = True
    
    # Get training indices
    train_indices = np.where(~test_mask)[0]
    
    # Select validation flare (rotate through training flares)
    val_idx = train_indices[test_idx % len(train_indices)]
    val_mask = np.zeros(len(X), dtype=bool)
    val_mask[val_idx] = True
    
    # Training mask
    train_mask = ~test_mask & ~val_mask
    
    print(f"   Train: {np.sum(train_mask)} flares")
    print(f"   Val: {flare_ids[val_idx]}")
    print(f"   Test: {test_flare}")
    
    # Create datasets with augmentation for training
    ds_train = FlareDataset(X[train_mask], Y_scaled[train_mask], 
                            GLOBAL_MEAN, GLOBAL_STD, augment=True)
    ds_val = FlareDataset(X[val_mask], Y_scaled[val_mask], 
                          GLOBAL_MEAN, GLOBAL_STD, augment=False)
    ds_test = FlareDataset(X[test_mask], Y_scaled[test_mask], 
                           GLOBAL_MEAN, GLOBAL_STD, augment=False)
    
    train_loader = DataLoader(ds_train, batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(ds_val, batch_size=1, shuffle=False)
    test_loader = DataLoader(ds_test, batch_size=1, shuffle=False)
    
    # Initialize model (AIA-only: 8 channels)
    model = ImprovedEUVRegressor(in_channels=8, out_features=3, dropout=0.3)  # ← CHANGED: explicit 8
    
    # Train
    model = train_with_validation(model, train_loader, val_loader, 
                                   epochs=EPOCHS, patience=50)
    
    # Save model
    model_path = f"results_aia_only/{test_flare}_model.pth"  # ← CHANGED folder
    torch.save(model.state_dict(), model_path)
    
    # Evaluate
    metrics = evaluate(model, test_loader)
    results.append((test_flare, metrics))
    
    # Save predictions
    np.savez(f"results_aia_only/{test_flare}_preds.npz",  # ← CHANGED folder
             flare=test_flare,
             preds=metrics['preds'],
             trues=metrics['trues'])
    
    fold_time = time.time() - fold_start_time
    
    print(f"\n   📊 Test Metrics:")
    print(f"      MAE: {metrics['mae']:.6e}")
    print(f"      Pearson r: {metrics['r']:.3f} (p={metrics['p_value']:.3e})")
    print(f"      R²: {metrics['r2']:.3f}")
    print(f"      Horizon MAE: T0={metrics['mae_per_horizon'][0]:.2e}, " +
          f"T1={metrics['mae_per_horizon'][1]:.2e}, T2={metrics['mae_per_horizon'][2]:.2e}")
    print(f"   ⏱️  Fold time: {fold_time/60:.1f} minutes")

total_time = time.time() - total_start_time

print("\n" + "="*70)
print("LOFO COMPLETE - AIA-ONLY BASELINE")  # ← CHANGED
print("="*70)
print(f"Total time: {total_time/60:.1f} minutes ({total_time/3600:.1f} hours)")
print(f"Avg per fold: {total_time/len(flare_ids)/60:.1f} minutes\n")

# Summary statistics (handle NaN for LOFO)
all_maes = [m['mae'] for _, m in results]
all_r2s = [m['r2'] for _, m in results if not np.isnan(m['r2'])]

print("SUMMARY STATISTICS:")
print(f"  MAE: {np.mean(all_maes):.6e} ± {np.std(all_maes):.6e}")

if len(all_r2s) > 0:
    print(f"  R² (where computable): {np.mean(all_r2s):.3f} ± {np.std(all_r2s):.3f}")
else:
    print(f"  R²: Not computable for single-sample LOFO")

print("\n  Note: Individual fold correlations not meaningful with 1 test sample.")
print("        Global metrics will be computed after aggregating all predictions.\n")

# Save summary with NaN handling
with open("results_aia_only/summary.csv", "w", newline="") as f:  # ← CHANGED folder
    w = csv.writer(f)
    w.writerow(["flare_id", "MAE", "MAE_T0", "MAE_T1", "MAE_T2"])
    for fid, m in results:
        w.writerow([
            fid, 
            f"{m['mae']:.6e}",
            f"{m['mae_per_horizon'][0]:.6e}",
            f"{m['mae_per_horizon'][1]:.6e}",
            f"{m['mae_per_horizon'][2]:.6e}"
        ])

print("✅ Results saved to results_aia_only/")  # ← CHANGED folder
# Out:
# ======================================================================
# LOFO CROSS-VALIDATION - AIA-ONLY BASELINE
# ======================================================================
# Total flares: 33
# Channels: 8 (AIA EUV/UV only)
# Train/Val/Test split: 31 / 1 / 1 per fold
# ======================================================================
#
# ======================================================================
# FOLD 1/33 | Test: AR11158_M6.6
# ======================================================================
#    Train: 31 flares
#    Val: AR11158_X2.2
#    Test: AR11158_M6.6
#    Training for up to 100 epochs (patience=50)...
#    Epoch 000/100 | Train=0.011007 | Val=0.012423 | LR=2.98e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 62
#      59 model = ImprovedEUVRegressor(in_channels=8, out_features=3, dropout=0.3)  # ← CHANGED: explicit 8
#      61 # Train
# ---> 62 model = train_with_validation(model, train_loader, val_loader,
#      63                                epochs=EPOCHS, patience=50)
#      65 # Save model
#      66 model_path = f"results_aia_only/{test_flare}_model.pth"  # ← CHANGED folder
#
# Cell In[6], line 78, in train_with_validation(model, train_loader, val_loader, epochs, patience)
#      75 train_loss = train_one_epoch(model, train_loader, optimizer)
#      77 # Validate
# ---> 78 val_loss = validate_epoch(model, val_loader)
#      80 # Step scheduler
#      81 scheduler.step()
#
# Cell In[6], line 38, in validate_epoch(model, loader)
#      35 xb = xb.to(device, dtype=torch.float32)
#      36 yb = yb.to(device, dtype=torch.float32)
# ---> 38 pred = model(xb)
#      39 loss = loss_fn_weighted(pred, yb)
#      40 val_losses.append(loss.item())
#
# File /opt/miniconda3/envs/surya_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/surya_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# Cell In[4], line 103, in ImprovedEUVRegressor.forward(self, x)
#     100 x = self.layer3(x)
#     101 x = self.attention3(x)
# --> 103 x = self.layer4(x)
#     104 x = self.attention4(x)
#     106 x = self.avgpool(x)
#
# File /opt/miniconda3/envs/surya_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/surya_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/surya_env/lib/python3.11/site-packages/torch/nn/modules/container.py:244, in Sequential.forward(self, input)
#     242 def forward(self, input):
#     243     for module in self:
# --> 244         input = module(input)
#     245     return input
#
# File /opt/miniconda3/envs/surya_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/surya_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/surya_env/lib/python3.11/site-packages/torchvision/models/resnet.py:97, in BasicBlock.forward(self, x)
#      94 out = self.relu(out)
#      96 out = self.conv2(out)
# ---> 97 out = self.bn2(out)
#      99 if self.downsample is not None:
#     100     identity = self.downsample(x)
#
# File /opt/miniconda3/envs/surya_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/surya_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/surya_env/lib/python3.11/site-packages/torch/nn/modules/batchnorm.py:193, in _BatchNorm.forward(self, input)
#     186     bn_training = (self.running_mean is None) and (self.running_var is None)
#     188 r"""
#     189 Buffers are only updated if they are to be tracked and we are in training mode. Thus they only need to be
#     190 passed when the update should occur (i.e. in training mode when they are tracked), or when buffer stats are
#     191 used for normalization (i.e. in eval mode when buffers are not None).
#     192 """
# --> 193 return F.batch_norm(
#     194     input,
#     195     # If buffers are not to be tracked, ensure that they won't be updated
#     196     self.running_mean
#     197     if not self.training or self.track_running_stats
#     198     else None,
#     199     self.running_var if not self.training or self.track_running_stats else None,
#     200     self.weight,
#     201     self.bias,
#     202     bn_training,
#     203     exponential_average_factor,
#     204     self.eps,
#     205 )
#
# File /opt/miniconda3/envs/surya_env/lib/python3.11/site-packages/torch/nn/functional.py:2817, in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2814 if training:
#    2815     _verify_batch_size(input.size())
# -> 2817 return torch.batch_norm(
#    2818     input,
#    2819     weight,
#    2820     bias,
#    2821     running_mean,
#    2822     running_var,
#    2823     training,
#    2824     momentum,
#    2825     eps,
#    2826     torch.backends.cudnn.enabled,
#    2827 )
#
# KeyboardInterrupt:

# %%
# %%
# ============================================================
# CELL 9: GLOBAL METRICS ACROSS ALL FOLDS (AIA-ONLY)
# ============================================================
print("\n" + "="*70)
print("COMPUTING GLOBAL METRICS ACROSS ALL FOLDS (AIA-ONLY)")  # ← CHANGED
print("="*70)

# Aggregate all predictions and targets
all_preds = np.concatenate([m['preds'] for _, m in results], axis=0)
all_trues = np.concatenate([m['trues'] for _, m in results], axis=0)

print(f"\nAggregated data:")
print(f"  Total samples: {len(all_preds)} flares × 3 horizons = {len(all_preds) * 3} predictions")
print(f"  Shape: preds={all_preds.shape}, trues={all_trues.shape}")

# Flatten for global correlation
preds_flat = all_preds.ravel()
trues_flat = all_trues.ravel()

# Global metrics
global_mae = mean_absolute_error(trues_flat, preds_flat)
global_r, global_p = pearsonr(trues_flat, preds_flat)
global_r2 = r2_score(trues_flat, preds_flat)

# Relative error
rel_errors = np.abs((preds_flat - trues_flat) / (trues_flat + 1e-8))
global_rel_error = np.mean(rel_errors) * 100

print(f"\n{'='*70}")
print("GLOBAL METRICS (Across All Folds) - AIA-ONLY BASELINE")  # ← CHANGED
print(f"{'='*70}")
print(f"  MAE: {global_mae:.6e} W/m²/nm")
print(f"  Pearson r: {global_r:.3f} (p={global_p:.3e})")
print(f"  R²: {global_r2:.3f}")
print(f"  Relative Error: {global_rel_error:.1f}%")

# Per-horizon global metrics
print(f"\nPer-Horizon Metrics:")
horizon_metrics = {}
for i, horizon in enumerate(['T0', 'T1', 'T2']):
    mae_h = mean_absolute_error(all_trues[:, i], all_preds[:, i])
    r_h, p_h = pearsonr(all_trues[:, i], all_preds[:, i])
    print(f"  {horizon:4s}: MAE={mae_h:.6e}, r={r_h:.3f}, p={p_h:.3e}")
    
    # Store as native Python floats for JSON
    horizon_metrics[horizon] = {
        'mae': float(mae_h),
        'r': float(r_h),
        'p': float(p_h)
    }

# Save global metrics (convert all numpy types to Python native types)
global_metrics = {
    'baseline': 'AIA-only (8 channels)',  # ← ADDED
    'global_mae': float(global_mae),
    'global_r': float(global_r),
    'global_r2': float(global_r2),
    'global_p_value': float(global_p),
    'global_rel_error_pct': float(global_rel_error),
    'num_folds': int(len(results)),
    'num_samples': int(len(all_preds)),
    'horizon_metrics': horizon_metrics
}

import json
with open("results_aia_only/global_metrics.json", "w") as f:  # ← CHANGED folder
    json.dump(global_metrics, f, indent=2)

print(f"\n✅ Global metrics saved to results_aia_only/global_metrics.json")  # ← CHANGED

# Interpretation
print(f"\n{'='*70}")
print("INTERPRETATION (AIA-ONLY BASELINE)")  # ← CHANGED
print(f"{'='*70}")

if global_r > 0.85:
    print("✅ EXCELLENT: r > 0.85 indicates strong predictive skill")
elif global_r > 0.70:
    print("✅ GOOD: r > 0.70 indicates reasonable predictive skill")
elif global_r > 0.50:
    print("⚠️  MODERATE: r > 0.50 suggests some predictive skill")
else:
    print("❌ POOR: r < 0.50 indicates weak predictive skill")

if global_r2 > 0.70:
    print(f"✅ Model explains {global_r2*100:.1f}% of variance")
elif global_r2 > 0.50:
    print(f"⚠️  Model explains {global_r2*100:.1f}% of variance (moderate)")
else:
    print(f"❌ Model explains only {global_r2*100:.1f}% of variance (poor)")

print("\n✅ Cell 9 complete! (AIA-only baseline)")  # ← CHANGED
# Out:
# ======================================================================
# COMPUTING GLOBAL METRICS ACROSS ALL FOLDS (AIA-ONLY)
# ======================================================================
#
# Aggregated data:
#   Total samples: 33 flares × 3 horizons = 99 predictions
#   Shape: preds=(33, 3), trues=(33, 3)
#
# ======================================================================
# GLOBAL METRICS (Across All Folds) - AIA-ONLY BASELINE
# ======================================================================
#   MAE: 5.377884e-06 W/m²/nm
#   Pearson r: 0.868 (p=3.461e-31)
#   R²: 0.746
#   Relative Error: 5.9%
#
# Per-Horizon Metrics:
#   T0  : MAE=5.105634e-06, r=0.903, p=7.059e-13
#   T1  : MAE=5.088143e-06, r=0.862, p=1.186e-10
#   T2  : MAE=5.939877e-06, r=0.840, p=1.025e-09
#
# ✅ Global metrics saved to results_aia_only/global_metrics.json
#
# ======================================================================
# INTERPRETATION (AIA-ONLY BASELINE)
# ======================================================================
# ✅ EXCELLENT: r > 0.85 indicates strong predictive skill
# ✅ Model explains 74.6% of variance
#
# ✅ Cell 9 complete! (AIA-only baseline)

# %%
# %%
# ============================================================
# CELL 10: GLOBAL SCATTER PLOT + DETAILED ANALYSIS (AIA-ONLY)
# ============================================================
from matplotlib import rcParams
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt
import os

# IEEE-style formatting
rcParams.update({
    "font.family": "Times New Roman",
    "font.size": 11,
    "axes.labelweight": "bold",
    "axes.labelsize": 11,
    "axes.titlesize": 11,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
    "axes.linewidth": 1.0,
    "legend.fontsize": 9,
    "legend.frameon": True,
    "grid.color": "0.85",
    "grid.linestyle": "--",
    "grid.linewidth": 0.6
})

print("\n" + "="*70)
print("GENERATING GLOBAL SCATTER PLOT (AIA-ONLY BASELINE)")  # ← CHANGED
print("="*70)

# Get flattened predictions
preds_flat = all_preds.ravel()
trues_flat = all_trues.ravel()

print(f"Plotting {len(preds_flat)} total predictions...")

# Create figure
fig, ax = plt.subplots(figsize=(6.5, 6), dpi=150)

# Scatter plot with different colors for each horizon
colors = ['#E74C3C', '#3498DB', '#2ECC71']  # Red, Blue, Green
labels = ['T0', 'T+1', 'T+2']

for i, (color, label) in enumerate(zip(colors, labels)):
    horizon_preds = all_preds[:, i]
    horizon_trues = all_trues[:, i]
    ax.scatter(horizon_trues, horizon_preds, 
              s=80, alpha=0.7, c=color, 
              edgecolors='black', linewidth=0.5,
              label=label, marker='o')

# 1:1 reference line
min_val = min(trues_flat.min(), preds_flat.min())
max_val = max(trues_flat.max(), preds_flat.max())
ax.plot([min_val, max_val], [min_val, max_val], 
        'k--', lw=2, alpha=0.8, label='1:1 line', zorder=1)

# Linear regression fit
lr = LinearRegression()
lr.fit(trues_flat.reshape(-1, 1), preds_flat)
pred_line = lr.predict(np.array([min_val, max_val]).reshape(-1, 1))
ax.plot([min_val, max_val], pred_line, 
        'gray', lw=2.5, alpha=0.6, linestyle='-',
        label=f'Fit: y={lr.coef_[0]:.2f}x{lr.intercept_:+.2e}')

# Labels and formatting
ax.set_xlabel('True EUV Irradiance (W/m²/nm)', fontweight='bold', fontsize=12)
ax.set_ylabel('Predicted EUV Irradiance (W/m²/nm)', fontweight='bold', fontsize=12)

# Title with metrics (mention AIA-only)  # ← CHANGED
title_text = (f'Global LOFO Performance - AIA-Only Baseline ({len(all_preds)} flares)\n'
             f'r = {global_r:.3f} | R² = {global_r2:.3f} | '
             f'MAE = {global_mae:.2e} W/m²/nm')
ax.set_title(title_text, fontweight='bold', fontsize=11, pad=12)

# Legend
ax.legend(loc='upper left', frameon=True, edgecolor='black', 
         fancybox=False, shadow=False, fontsize=10)

# Grid
ax.grid(True, alpha=0.4, linestyle='--', linewidth=0.6)

# Tight layout
plt.tight_layout()

# Save (with aia_only in filename)  # ← CHANGED
os.makedirs("figures", exist_ok=True)
plt.savefig("figures/global_scatter_aia_only.pdf", dpi=300, bbox_inches='tight')
plt.savefig("figures/global_scatter_aia_only.png", dpi=300, bbox_inches='tight')

print("\n✅ Saved:")
print("   - figures/global_scatter_aia_only.pdf")  # ← CHANGED
print("   - figures/global_scatter_aia_only.png")  # ← CHANGED

plt.show()

# ============================================================
# Per-Horizon Scatter Plots (Separate)
# ============================================================
print("\n" + "="*70)
print("GENERATING PER-HORIZON SCATTER PLOTS (AIA-ONLY)")  # ← CHANGED
print("="*70)

fig, axes = plt.subplots(1, 3, figsize=(15, 4.5), dpi=150)

for i, (ax, color, label) in enumerate(zip(axes, colors, labels)):
    horizon_preds = all_preds[:, i]
    horizon_trues = all_trues[:, i]
    
    # Scatter
    ax.scatter(horizon_trues, horizon_preds,
              s=100, alpha=0.7, c=color,
              edgecolors='black', linewidth=0.8)
    
    # 1:1 line
    h_min = min(horizon_trues.min(), horizon_preds.min())
    h_max = max(horizon_trues.max(), horizon_preds.max())
    ax.plot([h_min, h_max], [h_min, h_max],
           'k--', lw=2, alpha=0.8)
    
    # Linear fit
    lr_h = LinearRegression()
    lr_h.fit(horizon_trues.reshape(-1, 1), horizon_preds)
    pred_line_h = lr_h.predict(np.array([h_min, h_max]).reshape(-1, 1))
    ax.plot([h_min, h_max], pred_line_h,
           'gray', lw=2, alpha=0.6)
    
    # Metrics
    mae_h = mean_absolute_error(horizon_trues, horizon_preds)
    r_h, p_h = pearsonr(horizon_trues, horizon_preds)
    
    # Labels
    ax.set_xlabel('True (W/m²/nm)', fontweight='bold')
    ax.set_ylabel('Predicted (W/m²/nm)', fontweight='bold')
    ax.set_title(f'{label}: r={r_h:.3f}, MAE={mae_h:.2e}',
                fontweight='bold', fontsize=11)
    ax.grid(True, alpha=0.4)

plt.tight_layout()
plt.savefig("figures/per_horizon_scatter_aia_only.pdf", dpi=300, bbox_inches='tight')  # ← CHANGED
plt.savefig("figures/per_horizon_scatter_aia_only.png", dpi=300, bbox_inches='tight')  # ← CHANGED

print("\n✅ Saved:")
print("   - figures/per_horizon_scatter_aia_only.pdf")  # ← CHANGED
print("   - figures/per_horizon_scatter_aia_only.png")  # ← CHANGED

plt.show()

# ============================================================
# Residual Analysis
# ============================================================
print("\n" + "="*70)
print("RESIDUAL ANALYSIS (AIA-ONLY)")  # ← CHANGED
print("="*70)

residuals = preds_flat - trues_flat
relative_residuals = residuals / (trues_flat + 1e-8) * 100

fig, axes = plt.subplots(1, 2, figsize=(12, 4.5), dpi=150)

# Residuals vs Predicted
axes[0].scatter(preds_flat, residuals, 
               s=60, alpha=0.6, c='#3498DB',
               edgecolors='black', linewidth=0.5)
axes[0].axhline(y=0, color='red', linestyle='--', lw=2, alpha=0.8)
axes[0].set_xlabel('Predicted Irradiance (W/m²/nm)', fontweight='bold')
axes[0].set_ylabel('Residual (Pred - True)', fontweight='bold')
axes[0].set_title('Residual Plot (AIA-Only)', fontweight='bold')  # ← CHANGED
axes[0].grid(True, alpha=0.4)

# Residual histogram
axes[1].hist(relative_residuals, bins=15, 
            color='#2ECC71', alpha=0.7, 
            edgecolor='black', linewidth=1)
axes[1].axvline(x=0, color='red', linestyle='--', lw=2, alpha=0.8)
axes[1].set_xlabel('Relative Error (%)', fontweight='bold')
axes[1].set_ylabel('Frequency', fontweight='bold')
axes[1].set_title(f'Error Distribution (Mean: {relative_residuals.mean():.1f}%)',
                 fontweight='bold')
axes[1].grid(True, alpha=0.4, axis='y')

plt.tight_layout()
plt.savefig("figures/residual_analysis_aia_only.pdf", dpi=300, bbox_inches='tight')  # ← CHANGED
plt.savefig("figures/residual_analysis_aia_only.png", dpi=300, bbox_inches='tight')  # ← CHANGED

print("\n✅ Saved:")
print("   - figures/residual_analysis_aia_only.pdf")  # ← CHANGED
print("   - figures/residual_analysis_aia_only.png")  # ← CHANGED

plt.show()

# ============================================================
# Per-Flare Performance Summary
# ============================================================
print("\n" + "="*70)
print("PER-FLARE PERFORMANCE SUMMARY (AIA-ONLY)")  # ← CHANGED
print("="*70)

flare_names = [fid for fid, _ in results]
flare_maes = [m['mae'] for _, m in results]

# Sort by MAE
sorted_indices = np.argsort(flare_maes)
sorted_names = [flare_names[i] for i in sorted_indices]
sorted_maes = [flare_maes[i] for i in sorted_indices]

fig, ax = plt.subplots(figsize=(10, 6), dpi=150)  # ← CHANGED height for 33 flares

bars = ax.barh(range(len(sorted_names)), 
              np.array(sorted_maes) * 1e5,  # Scale to ×10⁻⁵
              color='#3498DB', alpha=0.7,
              edgecolor='black', linewidth=1)

# Color gradient (best to worst)
for i, bar in enumerate(bars):
    if i < len(bars) // 3:
        bar.set_color('#2ECC71')  # Green for best
    elif i < 2 * len(bars) // 3:
        bar.set_color('#3498DB')  # Blue for medium
    else:
        bar.set_color('#E74C3C')  # Red for worst

ax.set_yticks(range(len(sorted_names)))
ax.set_yticklabels(sorted_names, fontsize=8)  # ← CHANGED smaller font for 33 flares
ax.set_xlabel('MAE (×10⁻⁵ W/m²/nm)', fontweight='bold', fontsize=11)
ax.set_title('Per-Flare Prediction Error - AIA-Only (Best → Worst)',  # ← CHANGED
            fontweight='bold', fontsize=12)
ax.grid(True, alpha=0.4, axis='x')

# Add value labels
for i, (name, mae) in enumerate(zip(sorted_names, sorted_maes)):
    ax.text(mae * 1e5 + 0.3, i, f'{mae:.2e}',
           va='center', fontsize=7)  # ← CHANGED smaller font

plt.tight_layout()
plt.savefig("figures/per_flare_performance_aia_only.pdf", dpi=300, bbox_inches='tight')  # ← CHANGED
plt.savefig("figures/per_flare_performance_aia_only.png", dpi=300, bbox_inches='tight')  # ← CHANGED

print("\n✅ Saved:")
print("   - figures/per_flare_performance_aia_only.pdf")  # ← CHANGED
print("   - figures/per_flare_performance_aia_only.png")  # ← CHANGED

plt.show()

# Print summary table
print("\n" + "="*70)
print("FLARE PERFORMANCE TABLE (AIA-ONLY, Sorted by MAE)")  # ← CHANGED
print("="*70)
print(f"{'Rank':<5} {'Flare ID':<20} {'MAE (W/m²/nm)':<18} {'Quality'}")
print("-"*70)

for rank, (name, mae) in enumerate(zip(sorted_names, sorted_maes), 1):
    if mae < 5e-6:
        quality = "✅ Excellent"
    elif mae < 1e-5:
        quality = "✅ Good"
    elif mae < 1.5e-5:
        quality = "⚠️  Fair"
    else:
        quality = "❌ Challenging"
    
    print(f"{rank:<5} {name:<20} {mae:<18.6e} {quality}")

print("\n" + "="*70)
print("✅ CELL 10 COMPLETE - ALL AIA-ONLY VISUALIZATIONS GENERATED")  # ← CHANGED
print("="*70)
# Out:
# ======================================================================
# GENERATING GLOBAL SCATTER PLOT (AIA-ONLY BASELINE)
# ======================================================================
# Plotting 99 total predictions...
#
# ✅ Saved:
#    - figures/global_scatter_aia_only.pdf
#    - figures/global_scatter_aia_only.png
# ======================================================================
# GENERATING PER-HORIZON SCATTER PLOTS (AIA-ONLY)
# ======================================================================
#
# ✅ Saved:
#    - figures/per_horizon_scatter_aia_only.pdf
#    - figures/per_horizon_scatter_aia_only.png
# ======================================================================
# RESIDUAL ANALYSIS (AIA-ONLY)
# ======================================================================
#
# ✅ Saved:
#    - figures/residual_analysis_aia_only.pdf
#    - figures/residual_analysis_aia_only.png
# ======================================================================
# PER-FLARE PERFORMANCE SUMMARY (AIA-ONLY)
# ======================================================================
#
# ✅ Saved:
#    - figures/per_flare_performance_aia_only.pdf
#    - figures/per_flare_performance_aia_only.png
# ======================================================================
# FLARE PERFORMANCE TABLE (AIA-ONLY, Sorted by MAE)
# ======================================================================
# Rank  Flare ID             MAE (W/m²/nm)      Quality
# ----------------------------------------------------------------------
# 1     AR11283_M5.3         8.328643e-07       ✅ Excellent
# 2     AR11890_X1.1b        1.332252e-06       ✅ Excellent
# 3     AR11261_M6.0         1.835106e-06       ✅ Excellent
# 4     AR11429_M8.4         1.874146e-06       ✅ Excellent
# 5     AR11261_M9.3b        1.926475e-06       ✅ Excellent
# 6     AR11283_X1.8         2.006076e-06       ✅ Excellent
# 7     AR11944_M7.2         2.102800e-06       ✅ Excellent
# 8     AR11429_X1.3         2.341680e-06       ✅ Excellent
# 9     AR11877_M9.3         2.346111e-06       ✅ Excellent
# 10    AR11719_M6.5         2.398093e-06       ✅ Excellent
# 11    AR11283_X2.1         2.524085e-06       ✅ Excellent
# 12    AR11158_X2.2         2.662308e-06       ✅ Excellent
# 13    AR11515_M5.3         3.004568e-06       ✅ Excellent
# 14    AR11476_M5.7         3.079008e-06       ✅ Excellent
# 15    AR11890_X1.1a        3.560213e-06       ✅ Excellent
# 16    AR11158_M6.6         3.613175e-06       ✅ Excellent
# 17    AR11429_M6.3         3.761736e-06       ✅ Excellent
# 18    AR11936_M6.4         3.966406e-06       ✅ Excellent
# 19    AR11302_M7.4         3.969799e-06       ✅ Excellent
# 20    AR11261_M9.3         4.044783e-06       ✅ Excellent
# 21    AR11884_M6.3         4.566823e-06       ✅ Excellent
# 22    AR12035_X1.3         4.628249e-06       ✅ Excellent
# 23    AR11166_X1.5         5.242699e-06       ✅ Good
# 24    AR11402_M8.7         6.593541e-06       ✅ Good
# 25    AR11283_M6.7         6.861910e-06       ✅ Good
# 26    AR11515_M5.6         7.154000e-06       ✅ Good
# 27    AR11944_X1.2         7.365292e-06       ✅ Good
# 28    AR11515_M6.1         7.792354e-06       ✅ Good
# 29    AR11884_M5.0         9.445488e-06       ✅ Good
# 30    AR11520_X1.4         1.118126e-05       ⚠️  Fair
# 31    AR11429_X5.4         1.308138e-05       ⚠️  Fair
# 32    AR12036_M7.3         1.453513e-05       ⚠️  Fair
# 33    AR12017_X1.0         2.584038e-05       ❌ Challenging
#
# ======================================================================
# ✅ CELL 10 COMPLETE - ALL AIA-ONLY VISUALIZATIONS GENERATED
# ======================================================================

# %%
# %%
# ============================================================
# 📊 Global Metrics & Scatter Plot - AIA-Only (Current Results)
# ============================================================

import matplotlib.pyplot as plt
from matplotlib import rcParams
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score
from scipy.stats import pearsonr
import numpy as np
import json
import os

# --- Load results from AIA-only LOFO ---
results_folder = "results_aia_only"

# Load predictions from all folds
all_preds = []
all_trues = []

for npz_file in sorted(os.listdir(results_folder)):
    if npz_file.endswith("_preds.npz"):
        data = np.load(os.path.join(results_folder, npz_file))
        all_preds.append(data['preds'])
        all_trues.append(data['trues'])

# Concatenate all predictions
pred_all = np.concatenate(all_preds, axis=0)  # Shape: (33, 3)
true_all = np.concatenate(all_trues, axis=0)  # Shape: (33, 3)

# Flatten for global correlation
pred_flat = pred_all.ravel()
true_flat = true_all.ravel()

print("\n" + "="*70)
print("GLOBAL SCATTER PLOT - AIA-ONLY BASELINE")
print("="*70)
print(f"\nData loaded: {len(pred_all)} flares × 3 horizons = {len(pred_flat)} predictions")

# --- IEEE-style formatting ---
rcParams.update({
    "font.family": "Times New Roman",
    "font.size": 11,
    "axes.labelweight": "bold",
    "axes.labelsize": 11,
    "axes.titlesize": 11,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
    "axes.linewidth": 1.0,
    "legend.fontsize": 9,
    "legend.frameon": True,
    "grid.color": "0.85",
    "grid.linestyle": "--",
    "grid.linewidth": 0.6
})

# --- Compute metrics ---
corr_raw, p_value = pearsonr(true_flat, pred_flat)
r2 = r2_score(true_flat, pred_flat)
mae = mean_absolute_error(true_flat, pred_flat)
rel_err = np.mean(np.abs((pred_flat - true_flat) / (true_flat + 1e-8)))

# --- Linear correction fit ---
lr = LinearRegression().fit(pred_flat.reshape(-1, 1), true_flat)
pred_corrected = lr.predict(pred_flat.reshape(-1, 1))
corr_corr, _ = pearsonr(true_flat, pred_corrected)

print("\n--- Global Metrics (AIA-Only) ---")
print(f"Linear correction: y_true ≈ {lr.coef_[0]:.3f} * pred + {lr.intercept_:.3e}")
print(f"Raw correlation (r)       = {corr_raw:.3f} (p={p_value:.2e})")
print(f"Corrected correlation (r) = {corr_corr:.3f}")
print(f"Global R²                 = {r2:.3f}")
print(f"Global MAE                = {mae:.2e} W/m²/nm")
print(f"Global Relative Error     = {rel_err*100:.1f}%")

# --- Create scatter plot ---
fig, ax = plt.subplots(figsize=(6.5, 6), dpi=150)

# Plot raw and corrected predictions
ax.scatter(true_flat, pred_flat, 
          s=30, c="#FF6B6B", alpha=0.6,  # ← Orange-red for AIA
          edgecolors='black', linewidth=0.3,
          label=f"Raw (r={corr_raw:.3f})", 
          marker='o', zorder=3)

ax.scatter(true_flat, pred_corrected, 
          s=30, c="#4ECDC4", alpha=0.6,  # ← Teal for corrected
          edgecolors='black', linewidth=0.3,
          label=f"Corrected (r={corr_corr:.3f})", 
          marker='s', zorder=2)

# 1:1 reference line
min_val = min(true_flat.min(), pred_flat.min())
max_val = max(true_flat.max(), pred_flat.max())
ax.plot([min_val, max_val], [min_val, max_val], 
        'k--', lw=2, alpha=0.8, label='1:1 line', zorder=1)

# Correction line
ax.plot([min_val, max_val], 
        lr.predict(np.array([min_val, max_val]).reshape(-1, 1)),
        color='#4ECDC4', lw=2, alpha=0.4, linestyle='-',
        label=f'Fit: y={lr.coef_[0]:.2f}x{lr.intercept_:+.2e}',
        zorder=1)

# Labels and formatting
ax.set_xlabel('True EUV Irradiance (W/m²/nm)', fontweight='bold', fontsize=12)
ax.set_ylabel('Predicted EUV Irradiance (W/m²/nm)', fontweight='bold', fontsize=12)

# Title with metrics
title_text = (f'AIA-Only Baseline - Raw vs Corrected ({len(pred_all)} flares)\n'
             f'r = {corr_raw:.3f} | R² = {r2:.3f} | '
             f'MAE = {mae:.2e} W/m²/nm')
ax.set_title(title_text, fontweight='bold', fontsize=11, pad=12)

# Legend
ax.legend(loc='upper left', frameon=True, edgecolor='black', 
         fancybox=False, shadow=False, fontsize=10)

# Grid
ax.grid(True, alpha=0.4, linestyle='--', linewidth=0.6)

# Tight layout
plt.tight_layout()

# Save
os.makedirs("figures", exist_ok=True)
plt.savefig("figures/AIA_only_raw_corrected.pdf", dpi=600, bbox_inches='tight')
plt.savefig("figures/AIA_only_raw_corrected.png", dpi=600, bbox_inches='tight')

print("\n✅ Saved:")
print("   - figures/AIA_only_raw_corrected.pdf")
print("   - figures/AIA_only_raw_corrected.png")

plt.show()

# --- Save metrics to JSON ---
scatter_metrics = {
    'model': 'AIA-Only Baseline',
    'n_flares': int(len(pred_all)),
    'n_predictions': int(len(pred_flat)),
    'raw_correlation': float(corr_raw),
    'corrected_correlation': float(corr_corr),
    'r2': float(r2),
    'mae': float(mae),
    'relative_error_pct': float(rel_err * 100),
    'linear_fit': {
        'slope': float(lr.coef_[0]),
        'intercept': float(lr.intercept_)
    }
}

with open("figures/AIA_only_scatter_metrics.json", "w") as f:
    json.dump(scatter_metrics, f, indent=2)

print("   - figures/AIA_only_scatter_metrics.json")
print("\n" + "="*70)
# Out:
# ======================================================================
# GLOBAL SCATTER PLOT - AIA-ONLY BASELINE
# ======================================================================
#
# Data loaded: 33 flares × 3 horizons = 99 predictions
#
# --- Global Metrics (AIA-Only) ---
# Linear correction: y_true ≈ 0.918 * pred + 7.601e-06
# Raw correlation (r)       = 0.868 (p=3.46e-31)
# Corrected correlation (r) = 0.868
# Global R²                 = 0.746
# Global MAE                = 5.38e-06 W/m²/nm
# Global Relative Error     = 5.9%
#
# ✅ Saved:
#    - figures/AIA_only_raw_corrected.pdf
#    - figures/AIA_only_raw_corrected.png
#    - figures/AIA_only_scatter_metrics.json
#
# ======================================================================

# %%
# %%
# ============================================================
# LOAD RESULTS (AIA-ONLY BASELINE) → PREPARE GLOBAL METRICS
# ============================================================
import numpy as np
import os
from sklearn.metrics import mean_absolute_error, r2_score
from scipy.stats import pearsonr

results_folder = "results_aia_only"

# --- Load predictions & ground truth from NPZ files ---
all_preds = []
all_trues = []

for npz_file in sorted(os.listdir(results_folder)):
    if npz_file.endswith("_preds.npz"):
        data = np.load(os.path.join(results_folder, npz_file))
        all_preds.append(data['preds'])   # Shape: (1, 3)
        all_trues.append(data['trues'])   # Shape: (1, 3)

# --- Stack for global statistics ---
all_preds = np.concatenate(all_preds, axis=0)  # Shape: (33, 3)
all_trues = np.concatenate(all_trues, axis=0)  # Shape: (33, 3)

# --- Flatten for correlation/MAE ---
preds_flat = all_preds.ravel()
trues_flat = all_trues.ravel()

# --- Compute metrics ---
global_r, p_value = pearsonr(trues_flat, preds_flat)
global_mae = mean_absolute_error(trues_flat, preds_flat)

print("\n" + "="*70)
print("AIA-ONLY RESULTS — AGGREGATED METRICS")
print("="*70)
print(f"Total predictions: {len(preds_flat)} (33 flares × 3 horizons)")
print(f"Pearson r       = {global_r:.4f} (p = {p_value:.2e})")
print(f"MAE             = {global_mae:.3e} W/m²/nm")
print("="*70)
# Out:
# ======================================================================
# AIA-ONLY RESULTS — AGGREGATED METRICS
# ======================================================================
# Total predictions: 99 (33 flares × 3 horizons)
# Pearson r       = 0.8676 (p = 3.46e-31)
# MAE             = 5.378e-06 W/m²/nm
# ======================================================================

# %%
# %%
# ============================================================
# GLOBAL SCATTER PLOT – IEEE STYLE (AIA-ONLY, MAX QUALITY)
# ============================================================

from matplotlib import rcParams
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt
import os

# --- IEEE FONT & STYLE (BOOSTED SIZE FOR READABILITY) ---
rcParams.update({
    "font.family": "Times New Roman",
    "font.size": 13,           # ← bigger text
    "axes.labelsize": 13,
    "axes.titlesize": 13,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "legend.fontsize": 12,
    "axes.linewidth": 1.1,
})

print("\n" + "="*70)
print("GENERATING GLOBAL SCATTER PLOT — IEEE STYLE (AIA-ONLY, MAX SIZE)")
print("="*70)

# --- Flatten arrays ---
preds_flat = all_preds.ravel()
trues_flat = all_trues.ravel()

# --- Figure (FULL WIDTH FOR 2-COLUMN IEEE LAYOUT) ---
fig, ax = plt.subplots(figsize=(7.0, 6.0), dpi=450)   # 🔥 MAX SIZE (REVIEWER APPROVED)

# --- MARKERS & COLORS ---
markers = ['o', 's', '^']
colors = ['#1f77b4', '#2ca02c', '#d62728']   # IEEE-safe colors
labels = ['T0', 'T+1', 'T+2']

for i, (marker, color, label) in enumerate(zip(markers, colors, labels)):
    ax.scatter(all_trues[:, i], all_preds[:, i],
               s=90, marker=marker,
               c=color, alpha=0.75,
               edgecolors='black', linewidth=0.9,
               label=label, zorder=3)

# --- 1:1 LINE ---
min_val = min(trues_flat.min(), preds_flat.min())
max_val = max(trues_flat.max(), preds_flat.max())
ax.plot([min_val, max_val], [min_val, max_val], '--',
        lw=1.2, alpha=0.85, color="gray", label="Ideal 1:1")

# --- BEST FIT LINE ---
lr = LinearRegression()
lr.fit(trues_flat.reshape(-1, 1), preds_flat)
line = lr.predict(np.array([min_val, max_val]).reshape(-1, 1))
ax.plot([min_val, max_val], line,
        lw=1.5, linestyle='-', alpha=0.8,
        color="black", label="Best Fit")

# --- TITLE (ONLY r & MAE) ---
ax.set_title(
    f'AIA-Only Global Prediction (33 Flares)\n'
    f'r = {global_r:.3f}  |  MAE = {global_mae:.2e} W/m²/nm',
    fontweight='bold', pad=10
)

# --- AXES ---
ax.set_xlabel('True EUV Irradiance (W/m²/nm)', fontweight='bold')
ax.set_ylabel('Predicted EUV Irradiance (W/m²/nm)', fontweight='bold')

# --- LEGEND (BOTTOM RIGHT) ---
legend = ax.legend(loc='lower right', frameon=True, edgecolor='black')
legend.get_frame().set_alpha(0.92)
legend.get_frame().set_linewidth(1.0)

# --- GRID ---
ax.grid(alpha=0.5, linestyle='--', linewidth=0.6)

plt.tight_layout()

# --- SAVE (HIGH QUALITY @ 600 DPI) ---
os.makedirs("figures_ieee", exist_ok=True)
plt.savefig("figures_ieee/global_scatter_aia_only.pdf", dpi=600, bbox_inches='tight')
plt.savefig("figures_ieee/global_scatter_aia_only.png", dpi=600, bbox_inches='tight')

print("\n📌 Saved:")
print("  figures_ieee/global_scatter_aia_only.pdf")
print("  figures_ieee/global_scatter_aia_only.png")
plt.show()
# Out:
# ======================================================================
# GENERATING GLOBAL SCATTER PLOT — IEEE STYLE (AIA-ONLY, MAX SIZE)
# ======================================================================
#
# 📌 Saved:
#   figures_ieee/global_scatter_aia_only.pdf
#   figures_ieee/global_scatter_aia_only.png

# %%
# %%
# ============================================================
# GLOBAL SCATTER PLOT – IEEE STYLE (AIA-ONLY, MAX QUALITY)
# ============================================================

from matplotlib import rcParams
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from scipy.stats import pearsonr
import numpy as np
import matplotlib.pyplot as plt
import os

# --- LOAD RESULTS (AIA-ONLY) ---
results_folder = "results_aia_only"   # ⚠️ change if your folder name differs
all_preds, all_trues = [], []

for npz_file in sorted(os.listdir(results_folder)):
    if npz_file.endswith("_preds.npz"):
        data = np.load(os.path.join(results_folder, npz_file))
        all_preds.append(data["preds"])
        all_trues.append(data["trues"])

all_preds = np.concatenate(all_preds, axis=0)
all_trues = np.concatenate(all_trues, axis=0)

# --- Flatten arrays ---
preds_flat = all_preds.ravel()
trues_flat = all_trues.ravel()

# --- METRICS ---
global_r, pvalue = pearsonr(trues_flat, preds_flat)
global_mae = mean_absolute_error(trues_flat, preds_flat)

print("\n--- AIA-ONLY GLOBAL METRICS ---")
print(f"PCC = {global_r:.4f} (p={pvalue:.2e})")
print(f"MAE = {global_mae:.2e} W/m²/nm")

# --- IEEE FONT & STYLE (BOOSTED SIZE FOR READABILITY) ---
rcParams.update({
    "font.family": "Times New Roman",
    "font.size": 13,
    "axes.labelsize": 13,
    "axes.titlesize": 13,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "legend.fontsize": 12,
    "axes.linewidth": 1.1,
})

print("\n" + "="*70)
print("GENERATING GLOBAL SCATTER PLOT — IEEE STYLE (AIA-ONLY, MAX SIZE)")
print("="*70)

# --- Figure (FULL WIDTH FOR IEEE 2-COLUMN LAYOUT) ---
fig, ax = plt.subplots(figsize=(7.0, 6.0), dpi=450)

# --- MARKERS & COLORS ---
markers = ['o', 's', '^']
colors = ['#1f77b4', '#2ca02c', '#d62728']
labels = ['T0', r'T$_1$', r'T$_2$']   # ✅ IEEE subscripts

for i, (marker, color, label) in enumerate(zip(markers, colors, labels)):
    ax.scatter(all_trues[:, i], all_preds[:, i],
               s=90, marker=marker,
               c=color, alpha=0.75,
               edgecolors='black', linewidth=0.9,
               label=label, zorder=3)

# --- 1:1 LINE ---
min_val = min(trues_flat.min(), preds_flat.min())
max_val = max(trues_flat.max(), preds_flat.max())
ax.plot([min_val, max_val], [min_val, max_val], '--',
        lw=1.2, alpha=0.85, color="gray", label="Ideal 1:1")

# --- BEST FIT LINE ---
lr = LinearRegression()
lr.fit(trues_flat.reshape(-1, 1), preds_flat)
line = lr.predict(np.array([min_val, max_val]).reshape(-1, 1))
ax.plot([min_val, max_val], line,
        lw=1.5, linestyle='-', alpha=0.8,
        color="black", label="Best Fit")

# --- TITLE ---
ax.set_title(
    f'AIA-Only Global Prediction (33 Flares)\n'
    f'PCC = {global_r:.3f}  |  MAE = {global_mae:.2e} W/m²/nm',
    fontweight='bold', pad=10
)

# --- AXES ---
ax.set_xlabel('True EUV Irradiance (W/m²/nm)', fontweight='bold')
ax.set_ylabel('Predicted EUV Irradiance (W/m²/nm)', fontweight='bold')

# --- LEGEND ---
legend = ax.legend(loc='lower right', frameon=True, edgecolor='black')
legend.get_frame().set_alpha(0.92)
legend.get_frame().set_linewidth(1.0)

# --- GRID ---
ax.grid(alpha=0.5, linestyle='--', linewidth=0.6)

plt.tight_layout()

# --- SAVE HIGH QUALITY ---
os.makedirs("figures_ieee", exist_ok=True)
plt.savefig("figures_ieee/global_scatter_aia_only.pdf", dpi=600, bbox_inches='tight')
plt.savefig("figures_ieee/global_scatter_aia_only.png", dpi=600, bbox_inches='tight')

print("\n📌 Saved:")
print("  figures_ieee/global_scatter_aia_only.pdf")
print("  figures_ieee/global_scatter_aia_only.png")
plt.show()
# Out:
# --- AIA-ONLY GLOBAL METRICS ---
# PCC = 0.8676 (p=3.46e-31)
# MAE = 5.38e-06 W/m²/nm
#
# ======================================================================
# GENERATING GLOBAL SCATTER PLOT — IEEE STYLE (AIA-ONLY, MAX SIZE)
# ======================================================================
#
# 📌 Saved:
#   figures_ieee/global_scatter_aia_only.pdf
#   figures_ieee/global_scatter_aia_only.png
